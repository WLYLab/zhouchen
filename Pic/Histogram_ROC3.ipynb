# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
import pylab

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc


plt.figure(figsize=(12,10), dpi=300,facecolor=(1, 1, 1))#平铺画布，设置dpi300,注意，发表文章dpi不能低于300

# adjust distrances of subplots
plt.subplots_adjust(wspace =0.3, hspace =0.3)#调节子图之间的宽度 
plt.subplot(222)


data=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\1\AAC(N=1)_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#66c2a5',label=r'AntiCP_ACC(AUC=%.2f)'%roc_auc)

data=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\1\400D_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#fc8d62',label=r'AntiCP_DC(AUC=%.2f)'%roc_auc)

data=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\1\PseTrain_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8da0cb',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)

data=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\1\GAP126_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#e78ac3',label=r'iACP(AUC=%.2f)'%roc_auc)

data=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\1\ACPFL_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#a6d854',label=r"ACPred-FL(AUC=%.2f)"%roc_auc)

data=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\1\PEP_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#ffd92f',label=r'PEPred-Suite(AUC=%.2f)'%roc_auc)

data=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\1\FT174_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#e5c494',label=r'ACPred-Fuse(AUC=%.2f)'%roc_auc)





plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
# plt.text(0.4,0.53,'evaluated by NB',fontsize='x-large')
plt.text(-0.13,0.98,'B',fontsize='xx-large')
plt.legend(loc="lower right")

plt.subplot(223)


y1 = [0.822,0.826,0.683,0.830]#独立测试集
y2 = [0.879,0.884,0.695,0.855]
y3 = [0.853,0.858,0.695,0.851]
y4 = [0.899, 0.906, 0.683, 0.861]
y5 = [0.890,0.895,0.720,0.868]
y6 = [0.879, 0.885, 0.683, 0.853]
y7 = [0.877,0.888,0.549,0.761]


ind = np.arange(4)+2                # the x locations for the groups
width = 0.13
plt.bar(ind,y6,width,color = '#66c2a5',label = 'AntiCP_ACC',edgecolor = 'black') 
plt.bar(ind+width,y1,width,color = '#fc8d62',label = 'AntiCP_DC',edgecolor = 'black')  
plt.bar(ind+2*width,y2,width,color = '#8da0cb',label = 'Hajisharifi\'s_method',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+3*width,y7,width,color = '#e78ac3',label = 'iACP',edgecolor = 'black')
plt.bar(ind+4*width,y3,width,color = '#a6d854',label = "ACPred-FL",edgecolor = 'black')
plt.bar(ind+5*width,y4,width,color = '#ffd92f',label = 'PEPred-Suite',edgecolor = 'black')
plt.bar(ind+6*width,y5,width,color = '#e5c494',label = 'ACPred-Fuse',edgecolor = 'black')
plt.xticks(np.arange(4)+0.438 + 15*width, ('ACC','SP','SE','AUC'))
plt.text(1.15,1.01,'C',fontsize='xx-large')
# plt.legend(loc="upper right")
plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=8.05)
plt.title('Independent test')
# Independent Test
plt.ylim(0.45, 1.04)




plt.subplot(224)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\1\400Dclass.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 7])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g-',color = '#66c2a5',label=r'AntiCP_ACC(AUC=%.2f)'%roc_auc)

fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',color = '#fc8d62',label=r'AntiCP_DC(AUC=%.2f)'%roc_auc)

fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 3])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-',color = '#8da0cb',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)

fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 8])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',color = '#e78ac3',label=r'iACP(AUC=%.2f)'%roc_auc)

fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 4])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'y-',color = '#a6d854',label=r"ACPred-FL(AUC=%.2f)"%roc_auc)

fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 5])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g-',color = '#ffd92f',label=r'PEPred-Suite(AUC=%.2f)'%roc_auc)

fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 6])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',color = '#e5c494',label=r'ACPred-Fuse(AUC=%.2f)'%roc_auc)




plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Independent test',fontsize='x-large')
# plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.13,0.98,'D',fontsize='xx-large')
plt.legend(loc="lower right")
plt.subplot(221)

params={
# # #     'axes.labelsize': '35',
# # #     'xtick.labelsize':'27',
# # #     'ytick.labelsize':'27',
# # #     'lines.linewidth':2 ,
     'legend.fontsize': '9',
 
}
pylab.rcParams.update(params)

y1 = [0.746,0.776,0.716,0.825]
y2 = [0.754,0.836,0.672,0.831]
y3 = [0.780,0.844,0.716,0.846]
y4 = [0.804,0.880,0.728,0.860]
y5 = [0.824,0.876,0.772,0.882]
y6 = [0.726,0.784,0.668,0.824]
y7 = [0.706,0.840,0.572,0.809]






ind = np.arange(4)+2                # the x locations for the groups
width = 0.13
plt.bar(ind,y6,width,color = '#66c2a5',label = 'AntiCP_ACC',edgecolor = 'black') 
plt.bar(ind+width,y1,width,color = '#fc8d62',label = 'AntiCP_DC',edgecolor = 'black')  
plt.bar(ind+2*width,y2,width,color = '#8da0cb',label = 'Hajisharifi\'s_method',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+3*width,y7,width,color = '#e78ac3',label = 'iACP',edgecolor = 'black')
plt.bar(ind+4*width,y3,width,color = '#a6d854',label = "ACPred-FL",edgecolor = 'black')
plt.bar(ind+5*width,y4,width,color = '#ffd92f',label = 'PEPred-Suite',edgecolor = 'black')
plt.bar(ind+6*width,y5,width,color = '#e5c494',label = 'ACPred-Fuse',edgecolor = 'black')
plt.xticks(np.arange(4)+0.437 + 15*width, ('ACC','SP','SE','AUC'))

# plt.legend(loc="upper right",bbox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=8.05)
plt.title('Ten-fold cross validation')
plt.text(1.15,0.99,'A',fontsize='xx-large')
# Independent Test
plt.ylim(0.45, 1.02)
# plt.savefig('F:/past.pdf',bbox_inches='tight')
# plt.show()
plt.savefig(r'C:\Users\Administrator\Desktop\Figure6.pdf',bbox_inches='tight')
