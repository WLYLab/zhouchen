# %% [markdown]
# # line

# %%
#导入包
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import interp
import pylab
import matplotlib

params={
# # #     'axes.labelsize': '35',
   #  'legend.fontweight': 'bold',   
     'xtick.labelsize':'22',
    'ytick.labelsize':'22',
    # 'lines.linewidth':2 ,
     'legend.fontsize': '20',
#      'legend.weight': 'bold',
#      'xlabel.fontweight':'bold',
#      'ylabel.fontweight':'bold',
}
pylab.rcParams.update(params)
# font = {
        
#         'weight' : 'bold',
       
#         }
# mpl.rc('font',**font)


#pt=(fpr,tpr)
#y3=0.5
#创建figure窗口 ,dpi=300,facecolor=(1, 1, 1)
plt.figure(figsize=(30, 28),dpi=300,facecolor=(1, 1, 1))
#创建数据
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/posBit20(Nt2).csv",header=None,index_col=None)
x1, y1, y2= (data.values[:,0], data.values[:, 1], data.values[:, 2])
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/negBit20(Nt2).csv",header=None,index_col=None)
x2, y3, y4= (data.values[:,0], data.values[:, 1], data.values[:, 2])
plt.subplot(321)  
#画曲线1
#plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EEC900',label = 'Positive-AVG')
#画曲线2
plt.plot(x1, y2,'+', color='#EEC900',label = 'Positive-SD')
#画曲线3
plt.plot(x2, y3,'o', color='#36648B',label = 'Negative-AVG')
#画曲线4
plt.plot(x2, y4,'+', color='#36648B',label = 'Negative-SD')
plt.legend(loc="best")
#设置坐标轴范围
plt.xlim((-2, 44))
plt.ylim((-0.1, 1.1))
#设置坐标轴名称
plt.xlabel('Feature dimension',fontsize=19,)
plt.ylabel('Mean of subsample average / SD',fontsize=21)
plt.title('BPF(k=2)',fontsize=23,fontweight='bold')
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
plt.text(-6.2,1.03,'A',fontsize='34')
#设置坐标轴刻度
my_x_ticks = np.arange(0, 41, 10)
my_y_ticks = np.arange(0, 1.1, 0.2)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)

#显示出所有设置
#plt.show()
# plt.savefig('C:/Users/Administrator/Desktop/Ggap3.pdf',bbox_inches='tight')

#y3=0.5
#创建figure窗口
# plt.figure(num=2, figsize=(12, 5))
plt.subplot(322)  
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/posG-gap31.csv",header=None,index_col=None)
x1, y1, y2= (data.values[:,0], data.values[:, 1], data.values[:, 2])
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/negG-gap31.csv",header=None,index_col=None)
x2, y3, y4= (data.values[:,0], data.values[:, 1], data.values[:, 2])
#画曲线1
#plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EEC900',label = 'Positive-AVG')
#画曲线2
plt.plot(x1, y2,'+', color='#EEC900',label = 'Positive-SD')
#画曲线3
plt.plot(x2, y3,'o', color='#36648B',label = 'Negative-AVG')
#画曲线4
plt.plot(x2, y4,'+', color='#36648B',label = 'Negative-SD')
plt.legend(loc="best")
#设置坐标轴范围
plt.xlim((-20, 420))
plt.ylim((-0.1, 1.1))
#设置坐标轴名称
plt.xlabel('Feature dimension',fontsize=19,)
plt.ylabel('Mean of subsample average / SD',fontsize=21)
plt.title('GDC(g=3)',fontsize=23,fontweight='bold')
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
plt.text(-60.5,1.03,'B',fontsize='34')
#设置坐标轴刻度
my_x_ticks = np.arange(0, 401, 100)
my_y_ticks = np.arange(0, 1.1, 0.2)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)



plt.subplot(323)  
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/posOverlap(NT1).csv",header=None,index_col=None)
x1, y1, y2= (data.values[:,0], data.values[:, 1], data.values[:, 2])
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/negOverlap(NT1).csv",header=None,index_col=None)
x2, y3, y4= (data.values[:,0], data.values[:, 1], data.values[:, 2])
#画曲线1
#plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EEC900',label = 'Positive-AVG')
#画曲线2
plt.plot(x1, y2,'+', color='#EEC900',label = 'Positive-SD')
#画曲线3
plt.plot(x2, y3,'o', color='#36648B',label = 'Negative-AVG')
#画曲线4
plt.plot(x2, y4,'+', color='#36648B',label = 'Negative-SD')
plt.legend(loc="best")
#设置坐标轴范围
plt.xlim((-0.5, 10.5))
plt.ylim((-0.1, 1.1))
#设置坐标轴名称
plt.xlabel('Feature dimension',fontsize=19,)
plt.ylabel('Mean of subsample average / SD',fontsize=21)
plt.title('OPF(k=1)',fontsize=23,fontweight='bold')
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
plt.text(-1.5,1.03,'C',fontsize='34')
#设置坐标轴刻度
my_x_ticks = np.arange(0, 11, 2)
my_y_ticks = np.arange(0, 1.1, 0.2)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)


plt.subplot(324)  
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/posBit20(NT7).csv",header=None,index_col=None)
x1, y1, y2= (data.values[:,0], data.values[:, 1], data.values[:, 2])
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/negBit20(NT7).csv",header=None,index_col=None)
x2, y3, y4= (data.values[:,0], data.values[:, 1], data.values[:, 2])
#画曲线1
#plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EEC900',label = 'Positive-AVG')
#画曲线2
plt.plot(x1, y2,'+', color='#EEC900',label = 'Positive-SD')
#画曲线3
plt.plot(x2, y3,'o', color='#36648B',label = 'Negative-AVG')
#画曲线4
plt.plot(x2, y4,'+', color='#36648B',label = 'Negative-SD')
plt.legend(loc="best")
#设置坐标轴范围
plt.xlim((-7, 147))
plt.ylim((-0.1, 1.1))
#设置坐标轴名称
plt.xlabel('Feature dimension',fontsize=19,)
plt.ylabel('Mean of subsample average / SD',fontsize=21)
plt.title('BPF(k=7)',fontsize=23,fontweight='bold')
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
plt.text(-21.5,1.03,'D',fontsize='34')
#设置坐标轴刻度
my_x_ticks = np.arange(0, 141, 28)
my_y_ticks = np.arange(0, 1.1, 0.2)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)




plt.subplot(325)  
#画曲线1
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/posCTD1.csv",header=None,index_col=None)
x1, y1, y2= (data.values[:,0], data.values[:, 1], data.values[:, 2])
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/negCTD1.csv",header=None,index_col=None)
x2, y3, y4= (data.values[:,0], data.values[:, 1], data.values[:, 2])
#画曲线1
#plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EEC900',label = 'Positive-AVG')
#画曲线2
plt.plot(x1, y2,'+', color='#EEC900',label = 'Positive-SD')
#画曲线3
plt.plot(x2, y3,'o', color='#36648B',label = 'Negative-AVG')
#画曲线4
plt.plot(x2, y4,'+', color='#36648B',label = 'Negative-SD')
plt.legend(loc="best")
#设置坐标轴范围
plt.xlim((-4, 68))
plt.ylim((-0.1, 1.1))
#设置坐标轴名称
plt.xlabel('Feature dimension',fontsize=19,)
plt.ylabel('Mean of subsample average / SD',fontsize=21)
plt.title('CTD',fontsize=23,fontweight='bold')
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
plt.text(-10.6,1.03,'E',fontsize='34')
#设置坐标轴刻度
my_x_ticks = np.arange(0, 65, 16)
my_y_ticks = np.arange(0, 1.1, 0.2)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)



#y3=0.5
#创建figure窗口
# plt.figure(num=2, figsize=(12, 5))
plt.subplot(326)  
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/posFT5.csv",header=None,index_col=None)
x1, y1, y2= (data.values[:,0], data.values[:, 1], data.values[:, 2])
data=pd.read_csv(u"C:/Users/Administrator/Desktop/line_picture/negFT5.csv",header=None,index_col=None)
x2, y3, y4= (data.values[:,0], data.values[:, 1], data.values[:, 2])
#画曲线1
#plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EEC900',label = 'Positive-AVG')
#画曲线2
plt.plot(x1, y2,'+', color='#EEC900',label = 'Positive-SD')
#画曲线3
plt.plot(x2, y3,'o', color='#36648B',label = 'Negative-AVG')
#画曲线4
plt.plot(x2, y4,'+', color='#36648B',label = 'Negative-SD')
plt.legend(loc="best")
#设置坐标轴范围
plt.xlim((0.5, 6.9))
plt.ylim((-0.1, 1.1))
#设置坐标轴名称
plt.xlabel('Feature dimension',fontsize=19)
plt.ylabel('Mean of subsample average / SD',fontsize=21)
plt.title('The proposed features',fontsize=23,fontweight='bold')
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
plt.text(-0.06,1.03,'F',fontsize='34')
#设置坐标轴刻度
my_x_ticks = np.arange(1, 7, 1)
my_y_ticks = np.arange(0, 1.1, 0.2)
plt.xticks(my_x_ticks)
plt.yticks(my_y_ticks)

#显示出所有设置
#plt.show()
plt.savefig('C:/Users/Administrator/Desktop/AvgSD.pdf',bbox_inches='tight')
