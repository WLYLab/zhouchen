# %%
import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

plt.figure(figsize=(15,13), dpi=400,facecolor=(1, 1, 1))
plt.subplots_adjust(wspace =0.25, hspace =0.32)#调整子图间距
# plt.subplots()
# plt.tight_layout(h_pad=108)
# ax=plt.subplot(222)


ax=plt.subplot2grid((3,3), (0,0), colspan=1)
# ax=plt.subplot(221)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-angiogenic_Peptides\fastadata\ROCarff\400D8.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#008B45',linewidth=0.5,label=r'$ASDC$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-angiogenic_Peptides\fastadata\ROCarff\Ngram(N=2)2.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#CD950C',linewidth=0.5,label=r'$AAC(N=1)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-angiogenic_Peptides\fastadata\ROCarff\OVNTCT(5)96.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#36648B',linewidth=0.5,label=r'$OLP(NTCT=5)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-angiogenic_Peptides\fastadata\ROCarff\Bit21NTCT(5)95.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EE8262',linewidth=0.5,label=r'$BIT21(NTCT=5)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-angiogenic_Peptides\fastadata\ROCarff\NgramNTCT(5)99.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B6914',linewidth=0.5,label=r'$AAC(N=1;NTCT=5)$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\CPPred-natural.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr, color='#71C671', linestyle='-',linewidth=0.5,label=r'$CPPred-RF$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\FT6.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'-',color = '#4682B4',linewidth=0.5,label=r'$CPPred-FL(Class)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\result\training_set\FT26_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B7355',linewidth=0.5,label=r'$F26$(AUC=%.3f)'%roc_auc)
plt.title("Anti-angiogenic Peptides",fontsize="11")#设置标题了
plt.xlim([-0.03, 1.03])
plt.ylim([-0.03, 1.03])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-0.215,0.99,'A',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")

ax=plt.subplot2grid((3,3), (0,1), colspan=1)
# ax=plt.subplot(221)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-bacterial_Peptides\fastadata\ROCarff\8.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#008B45',linewidth=0.5,label=r'$ASDC$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-bacterial_Peptides\fastadata\ROCarff\5.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#CD950C',linewidth=0.5,label=r'$GGAP(G=1)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-bacterial_Peptides\fastadata\ROCarff\2.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#36648B',linewidth=0.5,label=r'$AAC(N=1)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-bacterial_Peptides\fastadata\ROCarff\4.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EE8262',linewidth=0.5,label=r'$GGAP(G=0)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-bacterial_Peptides\fastadata\ROCarff\9.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B6914',linewidth=0.5,label=r'$188D$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\CPPred-natural.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr, color='#71C671', linestyle='-',linewidth=0.5,label=r'$CPPred-RF$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\FT6.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'-',color = '#4682B4',linewidth=0.5,label=r'$CPPred-FL(Class)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\result\training_set\FT61_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B7355',linewidth=0.5,label=r'$F61$(AUC=%.3f)'%roc_auc)

plt.xlim([-0.03, 1.03])
plt.ylim([-0.03, 1.03])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("Anti-bacterial Peptides",fontsize="11")#设置标题了
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-0.215,0.99,'B',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")

ax=plt.subplot2grid((3,3), (0,2), colspan=1)
# ax=plt.subplot(221)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\ROCarff\Bit20NTCT(2)40.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#008B45',linewidth=0.5,label=r'$BIT20(NTCT=2)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\ROCarff\Bit21NT(2)29.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#CD950C',linewidth=0.5,label=r'$BIT21(NT=2)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\ROCarff\Bit20NT(2)28.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#36648B',linewidth=0.5,label=r'$BIT20(NT=2)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\ROCarff\Bit20NTCT(3)58.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EE8262',linewidth=0.5,label=r'$BIT20(NTCT=3)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-cancer_Peptides\fastadata\ROCarff\Bit20NT(4)64.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B6914',linewidth=0.5,label=r'$BIT20(NT=4)$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\CPPred-natural.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr, color='#71C671', linestyle='-',linewidth=0.5,label=r'$CPPred-RF$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\FT6.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'-',color = '#4682B4',linewidth=0.5,label=r'$CPPred-FL(Class)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\result\training_set\FT45_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B7355',linewidth=0.5,label=r'$F45$(AUC=%.3f)'%roc_auc)

plt.xlim([-0.03, 1.03])
plt.ylim([-0.03, 1.03])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.title("Anti-cancer Peptides",fontsize="11")#设置标题了
plt.text(-0.215,0.99,'C',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")




ax=plt.subplot2grid((3,3), (1,0), colspan=1)
# ax=plt.subplot(221)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-inflammatory_Peptides\fastadata\ROCarff\GAP5.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#008B45',linewidth=0.5,label=r'$GGAP(G=1)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-inflammatory_Peptides\fastadata\ROCarff\CTD3.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#CD950C',linewidth=0.5,label=r'$CTD$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-inflammatory_Peptides\fastadata\ROCarff\Ngram(N=1)1.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#36648B',linewidth=0.5,label=r'$AAC(N=1)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-inflammatory_Peptides\fastadata\ROCarff\188D9.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EE8262',linewidth=0.5,label=r'$188D$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-inflammatory_Peptides\fastadata\ROCarff\GAP4.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B6914',linewidth=0.5,label=r'$GGAP(G=0)$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\CPPred-natural.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr, color='#71C671', linestyle='-',linewidth=0.5,label=r'$CPPred-RF$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\FT6.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'-',color = '#4682B4',linewidth=0.5,label=r'$CPPred-FL(Class)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\result\training_set\FT891_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B7355',linewidth=0.5,label=r'$F89$(AUC=%.3f)'%roc_auc)
plt.xlim([-0.03, 1.03])
plt.ylim([-0.03, 1.03])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("Anti-inflammatory Peptides",fontsize="11")#设置标题了
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-0.215,0.99,'D',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")

ax=plt.subplot2grid((3,3), (1,1), colspan=1)
# ax=plt.subplot(221)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-viral_Peptides\fastadata\ROCarff\GAP4.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#008B45',linewidth=0.5,label=r'$GGAP(G=0)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-viral_Peptides\fastadata\ROCarff\400D8.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#CD950C',linewidth=0.5,label=r'$ASDC$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-viral_Peptides\fastadata\ROCarff\Ngram(N=2)2.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#36648B',linewidth=0.5,label=r'$AAC(N=2)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-viral_Peptides\fastadata\ROCarff\GAP6.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EE8262',linewidth=0.5,label=r'$GGAP(G=2)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-viral_Peptides\fastadata\ROCarff\GAP5.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B6914',linewidth=0.5,label=r'$GGAP(G=1)$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\CPPred-natural.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr, color='#71C671', linestyle='-',linewidth=0.5,label=r'$CPPred-RF$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\FT6.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'-',color = '#4682B4',linewidth=0.5,label=r'$CPPred-FL(Class)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Anti-viral_Peptides\fastadata\ROCFTc\FT89.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B7355',linewidth=0.5,label=r'$F89$(AUC=%.3f)'%roc_auc)

plt.xlim([-0.03, 1.03])
plt.ylim([-0.03, 1.03])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("Anti-viral Peptides",fontsize="11")#设置标题了
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-0.215,0.99,'E',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")

ax=plt.subplot2grid((3,3), (1,2), colspan=1)
# ax=plt.subplot(221)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Cell-penetrating_Peptides\fastadata\ROCarff\1.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#008B45',linewidth=0.5,label=r'$AAC(N=1)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Cell-penetrating_Peptides\fastadata\ROCarff\8.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#CD950C',linewidth=0.5,label=r'$ASDC$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Cell-penetrating_Peptides\fastadata\ROCarff\9.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#36648B',linewidth=0.5,label=r'$188D$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Cell-penetrating_Peptides\fastadata\ROCarff\4.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EE8262',linewidth=0.5,label=r'$GGAP(G=0)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Cell-penetrating_Peptides\fastadata\ROCarff\6.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B6914',linewidth=0.5,label=r'$GGAP(G=2)$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\CPPred-natural.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr, color='#71C671', linestyle='-',linewidth=0.5,label=r'$CPPred-RF$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\FT6.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'-',color = '#4682B4',linewidth=0.5,label=r'$CPPred-FL(Class)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\result\training_set\FT96_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B7355',linewidth=0.5,label=r'$F96$(AUC=%.3f)'%roc_auc)

plt.xlim([-0.03, 1.03])
plt.ylim([-0.03, 1.03])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("Cell-penetrating Peptides",fontsize="11")#设置标题了
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-0.215,0.99,'F',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")




ax=plt.subplot2grid((3,3), (2,0), colspan=1)
# ax=plt.subplot(221)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Quorum-Sensing_Peptides\fastadata\ROCarff\GAP4.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#008B45',linewidth=0.5,label=r'$GGAP(G=0)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Quorum-Sensing_Peptides\fastadata\ROCarff\GAP6.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#CD950C',linewidth=0.5,label=r'$GGAP(G=2)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Quorum-Sensing_Peptides\fastadata\ROCarff\188D9.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#36648B',linewidth=0.5,label=r'$188D$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Quorum-Sensing_Peptides\fastadata\ROCarff\CTD3.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EE8262',linewidth=0.5,label=r'$CTD$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Quorum-Sensing_Peptides\fastadata\ROCarff\Ngram(N=2)2.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B6914',linewidth=0.5,label=r'$AAC(N=1)$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\CPPred-natural.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr, color='#71C671', linestyle='-',linewidth=0.5,label=r'$CPPred-RF$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\FT6.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'-',color = '#4682B4',linewidth=0.5,label=r'$CPPred-FL(Class)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\result\training_set\FT92_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B7355',linewidth=0.5,label=r'$F92$(AUC=%.3f)'%roc_auc)

plt.xlim([-0.03, 1.03])
plt.ylim([-0.03, 1.03])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("Quorum-Sensing Peptides",fontsize="11")#设置标题了
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-0.215,0.99,'G',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")

ax=plt.subplot2grid((3,3), (2,1), colspan=1)
# ax=plt.subplot(221)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Surface-Binding_Peptides\fastadata\ROCarff\1.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#008B45',linewidth=0.5,label=r'$AAC(N=1)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Surface-Binding_Peptides\fastadata\ROCarff\9.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#CD950C',linewidth=0.5,label=r'$188D$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Surface-Binding_Peptides\fastadata\ROCarff\8.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#36648B',linewidth=0.5,label=r'$ASDC$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Surface-Binding_Peptides\fastadata\ROCarff\7.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EE8262',linewidth=0.5,label=r'$GGAP(G=3)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\Surface-Binding_Peptides\fastadata\ROCarff\66.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B6914',linewidth=0.5,label=r'$OLP(NT=4)$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\CPPred-natural.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr, color='#71C671', linestyle='-',linewidth=0.5,label=r'$CPPred-RF$(AUC=%.3f)'%roc_auc)
# data=pd.read_csv(u"E:\ROC\FT6.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'-',color = '#4682B4',linewidth=0.5,label=r'$CPPred-FL(Class)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\result\training_set\FT8_RF_predict.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B7355',linewidth=0.5,label=r'$F8$(AUC=%.3f)'%roc_auc)

plt.xlim([-0.03, 1.03])
plt.ylim([-0.03, 1.03])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("Surface-Binding Peptides",fontsize="11")#设置标题了
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-0.215,0.99,'H',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")


# plt.savefig('C:\Users\Administrator\Desktop\ROC_3.pdf',bbox_inches='tight')
plt.show()
