# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

plt.figure(figsize=(13,10), dpi=200,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=108)
# ax=plt.subplot(222)
ax=plt.subplot2grid((2,10), (0,6), colspan=4)
#数据
name=[ 'CPPred-FL(Prob)  ','CPPred-FL(CLass)  ','CPPred-RF ','SkipCPP-Pred  ','Diener\'s method ','CellPPD-3 ','CellPPD-2 ','CellPPD-1 ']
colleges=[19,6,290,400,27,20,400,20]
b=ax.barh(range(len(name)),colleges,color='w',edgecolor = 'black')
#添加数据标签
for rect in b:
    w=rect.get_width()
    ax.text(w,rect.get_y()+rect.get_height()/2,'%d'%int(w),ha='left',va='center')

#设置Y轴刻度线标签
ax.set_yticks(range(len(name)))
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
# ax.set_yticklabels(name)
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
ax.set_yticklabels(name,fontsize="8")
plt.text(-52.15,7.5,'B',fontsize='xx-large')
plt.xlim([0, 450])
plt.xlabel('Feature Dimension')
# Independent Test

ax=plt.subplot2grid((2,10), (0,0), colspan=5)
# ax=plt.subplot(221)
data=pd.read_csv(u"E:\ROC\CellPPD1natural.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#008B45',linewidth=0.5,label=r'$CellPPD-1$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"E:\ROC\CellPPD-2-natural.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#CD950C',linewidth=0.5,label=r'$CellPPD-2$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"E:\ROC\CellPPD-3-natural.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#36648B',linewidth=0.5,label=r'$CellPPD-3$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"E:\ROC\D-method-CPP924.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EE8262',linewidth=0.5,label=r'$Diener\'s method$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"E:\ROC\SkipCPP-Pred-natural.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B6914',linewidth=0.5,label=r'$SkipCPP-Pred$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"E:\ROC\CPPred-natural.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='#71C671', linestyle='-',linewidth=0.5,label=r'$CPPred-RF$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"E:\ROC\FT6.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 1])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#4682B4',linewidth=0.5,label=r'$CPPred-FL(Class)$(AUC=%.3f)'%roc_auc)
data=pd.read_csv(u"E:\ROC\FT19.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 1])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B7355',linewidth=0.5,label=r'$CPPred-FL(Prob)$(AUC=%.3f)'%roc_auc)

plt.xlim([-0.03, 1.03])
plt.ylim([-0.03, 1.03])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-0.15,0.99,'A',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")


ax=plt.subplot2grid((2,10), (1,0), colspan=10)
# ax=plt.subplot(212)
y1 = [0.907,0.909,0.905,0.816]
y2 = [0.87,0.907,0.833,0.745]
y3 = [0.837,0.781,0.892,0.680]
y4 = [0.906,0.885,0.926,0.812]
y5 = [0.912,0.903,0.922,0.825]
y6 = [0.916,0.905,0.926,0.831]
y7 = [0.912,0.92,0.905,0.825]
y8 = [0.921,0.924,0.918,0.842]
ind = np.arange(4)+2                # the x locations for the groups
width = 0.1
plt.bar(ind,y1,width,color = '#008B45',label = 'CellPPD-1',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'CellPPD-2',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label =  'CellPPD-3 ',edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'SkipCPP-Pred',edgecolor = 'black')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label ='Diener\'s method ',edgecolor = 'black')
plt.bar(ind+5*width,y6,width,color = '#71C671',label = "CPPred-RF",edgecolor = 'black')
plt.bar(ind+6*width,y7,width,color = '#4682B4',label = 'CPPred-FL(Class)',edgecolor = 'black')
plt.bar(ind+7*width,y8,width,color = '#8B7355',label = 'CPPred-FL(Prob)',edgecolor = 'black')
plt.xticks(np.arange(4)+0.5 + 18.5*width, ('ACC','SE','SP','MCC'))
# plt.legend(loc="upper right",bbox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
# # plt.title('Ten-fold cross validation')
# plt.text(1.15,0.99,'A',fontsize='xx-large')
# Independent Test
plt.ylim(0.6, 1.02)
# plt.xlabel('False Positive Rate')
plt.ylabel('Performance(%)')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(1.5,0.99,'C',fontsize='xx-large')
plt.legend(loc="best",fontsize="8")
plt.savefig('C:\Users\Administrator\Desktop\ROC_2.pdf',bbox_inches='tight')


# plt.show()
