# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

plt.figure(figsize=(12,12), dpi=300,facecolor=(1, 1, 1))#平铺画布，设置dpi300,注意，发表文章dpi不能低于300

#adjust distrances of subplots
plt.subplots_adjust(wspace =0.3, hspace =0.3)#调节子图之间的宽度 
model=TSNE(n_components=2,random_state=0)
ax2=plt.subplot(321)
data1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\ZSCALENT(10).csv",header=None,index_col=None)
labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\ZSCALENT(10)class.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label==0.0) ]
p2=tsne_df[(tsne_df.label==1.0) ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
##plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='3')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='3')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('ZSC(NT10)',fontsize=12)
plt.legend(loc="upper right")
plt.text(-55.5,26,'A',fontsize='15')
plt.xlim((-43, 43))
plt.ylim((-28, 28))

ax2=plt.subplot(322)
data1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\FT36.csv",header=None,index_col=None)
labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\FT36class.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label==0.0) ]
p2=tsne_df[(tsne_df.label==1.0) ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
#plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='3')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='3')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('F36_p',fontsize=12)
plt.legend(loc="upper right")
plt.text(-55.5,30,'B',fontsize='15')
plt.xlim((-43, 43))
plt.ylim((-40, 35))


ax2=plt.subplot(323)
data1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\FT107.csv",header=None,index_col=None)
labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\FT107class.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label==0.0) ]
p2=tsne_df[(tsne_df.label==1.0) ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
#plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='3')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='3')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('F107_c',fontsize=12)
plt.legend(loc="upper right")
plt.text(-55.5,30,'C',fontsize='15')
plt.xlim((-43, 43))
plt.ylim((-35, 35))

# ax2=plt.subplot(322)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\CTDC.csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\CTDC1.csv",header=None,index_col=None)
# tsne_data1=model.fit_transform(data1)
# tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
# tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
# p1=tsne_df[(tsne_df.label==0.0) ]
# p2=tsne_df[(tsne_df.label==1.0) ]
# x1=p1.values[:,0]
# y1=p1.values[:,1]
# x2=p2.values[:,0]
# y2=p2.values[:,1]
# #plt.plot(x, y1)
# plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='3')
# #画曲线2
# plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='3')
# # ax.scatter(x1,y1,c = 'r',marker = 'o')  
# # ax.scatter(x2,y2,c = 'b',marker = 'o')  
# plt.xlabel('Dimension1',fontsize=9)
# plt.ylabel('Dimension2',fontsize=9)
# plt.title('CTDC',fontsize=12)
# plt.legend(loc="upper right")
# plt.text(-55.5,30,'B',fontsize='15')
# plt.xlim((-43, 43))
# plt.ylim((-35, 35))

# ax2=plt.subplot(323)
# data1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\AAC(N=2).csv",header=None,index_col=None)
# labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\AAC(N=2)class.csv",header=None,index_col=None)
# tsne_data1=model.fit_transform(data1)
# tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
# tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
# p1=tsne_df[(tsne_df.label==0.0) ]
# p2=tsne_df[(tsne_df.label==1.0) ]
# x1=p1.values[:,0]
# y1=p1.values[:,1]
# x2=p2.values[:,0]
# y2=p2.values[:,1]
# #plt.plot(x, y1)
# plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='3')
# #画曲线2
# plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='3')
# # ax.scatter(x1,y1,c = 'r',marker = 'o')  
# # ax.scatter(x2,y2,c = 'b',marker = 'o')  
# plt.xlabel('Dimension1',fontsize=9)
# plt.ylabel('Dimension2',fontsize=9)
# plt.title('AAC(N=2)',fontsize=12)
# plt.legend(loc="upper right")
# plt.text(-55.5,26,'C',fontsize='15')
# plt.xlim((-43, 43))
# plt.ylim((-35, 35))


ax2=plt.subplot(324)
data1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\FT174.csv",header=None,index_col=None)
labels1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\FT174class.csv",header=None,index_col=None)
tsne_data1=model.fit_transform(data1)
tsne_data1=np.vstack((tsne_data1.T,labels1.T)).T
tsne_df=pd.DataFrame(data=tsne_data1,columns=("Dimension1","Dimension2","label"))
p1=tsne_df[(tsne_df.label==0.0) ]
p2=tsne_df[(tsne_df.label==1.0) ]
x1=p1.values[:,0]
y1=p1.values[:,1]
x2=p2.values[:,0]
y2=p2.values[:,1]
#plt.plot(x, y1)
plt.plot(x1, y1,'o', color='#EE7621',label = 'Positive',markersize='3')
#画曲线2
plt.plot(x2, y2,'o', color='#36648B',label = 'Negative',markersize='3')
# ax.scatter(x1,y1,c = 'r',marker = 'o')  
# ax.scatter(x2,y2,c = 'b',marker = 'o')  
plt.xlabel('Dimension1',fontsize=9)
plt.ylabel('Dimension2',fontsize=9)
plt.title('F_fuse',fontsize=12)
plt.legend(loc="upper right")
plt.text(-55.5,30,'D',fontsize='15')
plt.xlim((-43, 43))
plt.ylim((-35, 35))
# plt.show()
plt.savefig(r'C:\Users\Administrator\Desktop\Figure4.pdf',bbox_inches='tight')
