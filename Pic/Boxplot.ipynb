# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

#data preprocessing
iris = sns.load_dataset("iris") #加载iris公共数据
# iris.loc(["sepal_length","species"]) #选取sepal_length和species这两列属性
# data=iris[(iris.species=="setosa") | (iris.species=="virginica")]#筛选出iris的species列中值为setosa和virginica的数据
data1=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\FT36_xiang.csv",header=0,index_col=None)
data2=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\FT107_xiang.csv",header=0,index_col=None)
data3=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\FT174_xiang.csv",header=0,index_col=None)
data4=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\ZSCALENT(10)_RF_predict_xiang.csv",header=0,index_col=None)
# data5=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim\Result_FT17_xiang.csv",header=0,index_col=None)
# data6=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim\Result_FT10_xiang.csv",header=0,index_col=None)
# data7=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim\Result_FT23_xiang.csv",header=0,index_col=None)
# data8=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim\Result_FT231_xiang.csv",header=0,index_col=None)
# x1, y1= (data2.values[:,1], data2.values[:, 0])
# x1= data1.values[:,1]
# y1= data1.values[:,0]
# print data2
# print x1,y1
#define a panel with size (12,12) and 300 dpi
plt.figure(figsize=(7,7), dpi=300,facecolor=(1, 1, 1))#平铺画布，设置dpi300,注意，发表文章dpi不能低于300

#adjust distrances of subplots
plt.subplots_adjust(wspace =0.3, hspace =0.25)#调节子图之间的宽度
# 
# #plot multi sub figures into one figure
# ax2=plt.subplot(221)#前面的33代表三行三列，其实更加具体的写法为plt.subplot(3,3,1),1代表第一张子图，
# ax=sns.boxplot(data=data1) #palette是画板的意思，data为数据，
# ax.set_xlabel('')#设置x轴标签为空
# plt.xticks(rotation=50)
# ax.text(-1,1.1,'A',fontsize=15)#在图中写文字，其中的两个数字要经常调整到合适的位置
# ax.text(3.3,1.1,'enhancers',fontsize=15)

# ax2=plt.subplot(222)#前面的33代表三行三列，其实更加具体的写法为plt.subplot(3,3,1),1代表第一张子图，
# ax=sns.boxplot(data=data2) #palette是画板的意思，data为数据，
# ax.set_xlabel('')#设置x轴标签为空
# plt.xticks(rotation=50)
# ax.text(-1,1.1,'B',fontsize=15)#在图
# ax.text(3.3,1.1,'non-enhancers',fontsize=15)

# ax2=plt.subplot(223)#前面的33代表三行三列，其实更加具体的写法为plt.subplot(3,3,1),1代表第一张子图，
# ax=sns.boxplot(data=data3) #palette是画板的意思，data为数据，
# ax.set_xlabel('')#设置x轴标签为空
# plt.xticks(rotation=50)
# ax.text(-1,1.02,'C',fontsize=15)#在图
# ax.text(3,1.02,'strong enhancers',fontsize=15)

# ax2=plt.subplot(224)#前面的33代表三行三列，其实更加具体的写法为plt.subplot(3,3,1),1代表第一张子图，
# ax=sns.boxplot(data=data4) #palette是画板的意思，data为数据，
# ax.set_xlabel('')#设置x轴标签为空
# ax.text(-1,0.97,'D',fontsize=15)#在图
# plt.xticks(rotation=50)
# ax.text(3,0.97,'weak enhancers',fontsize=15)
plt.subplot(221)
ax=sns.boxplot(data=data4,palette=("#6699cc", "#CB9898"))
ax.set_xlabel('',fontsize=15)
ax.text(-0.951,1.045,'A',fontsize=10)
ax.text(0.23,1.045,'ZSC(NT10)',fontsize=10)
plt.ylabel('Confidence',fontsize=10)
plt.subplot(222)
ax=sns.boxplot(data=data2,palette=("#6699cc", "#CB9898"))
ax.set_xlabel('')
ax.text(-0.951,1.05,'B',fontsize=10)
ax.text(0.3,1.05,'F107_c',fontsize=10)
plt.ylabel('Confidence',fontsize=10)
plt.subplot(223)
ax=sns.boxplot(data=data1,palette=("#6699cc", "#CB9898"))
ax.set_xlabel('')
ax.text(-0.951,1.08,'C',fontsize=10)
ax.text(0.34,1.08,'F36_p',fontsize=10)
plt.ylabel('Confidence',fontsize=10)
plt.subplot(224)
ax=sns.boxplot(data=data3,palette=("#6699cc", "#CB9898"))
ax.set_xlabel('')
ax.text(-0.951,1.08,'D',fontsize=10)
ax.text(0.24,1.065,'ACPred-Fuse',fontsize=10)
plt.ylabel('Confidence',fontsize=10)
# plt.subplot(335)
# ax=sns.boxplot(data=data5,palette=("#6699cc", "#CB9898"))
# ax.set_xlabel('')
# ax.text(-1,1.0,'(E)',fontsize=15)
# plt.subplot(336)
# ax=sns.boxplot(data=data6,palette=("#6699cc", "#CB9898"))
# ax.set_xlabel('')
# ax.text(-1,1.0,'(F)',fontsize=15)
# plt.subplot(337)
# ax=sns.boxplot(data=data7,palette=("#6699cc", "#CB9898"))
# ax.set_xlabel('')
# ax.text(-1,1.0,'(G)',fontsize=15)
# plt.subplot(338)
# ax=sns.boxplot(data=data8,palette=("#6699cc", "#CB9898"))
# ax.set_xlabel('')
# ax.text(-1,1.0,'(H)',fontsize=15)

# show figure 
# plt.show()
plt.savefig(r'C:\Users\Administrator\Desktop\Figure4.pdf',bbox_inches='tight')
#
