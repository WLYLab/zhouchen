# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
import pylab

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc
import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties




plt.figure(figsize=(12,8), dpi=300,facecolor=(1, 1, 1))
plt.subplots_adjust(wspace =0.2, hspace =0.62)#调整子图间距
ax=plt.subplot2grid((2,2), (0,1), colspan=1)

# params={
# # # #     'axes.labelsize': '35',
# # # #     'xtick.labelsize':'27',
# # # #     'ytick.labelsize':'27',
# # # #     'lines.linewidth':2 ,
#      'legend.fontsize': '9',
 
# }
# pylab.rcParams.update(params)

y1 = [0.78,0.842,0.86,0.74,0.562]
y2 = [0.806,0.875,0.852,0.76,0.615]
y3 = [0.816,0.878,0.852,0.764,0.635]
y4 = [0.824,0.882,0.876,0.772,0.652]
# y5 = [0.914,0.98,0.848,0.835,0.652]






ind = np.arange(5)+2                # the x locations for the groups
width = 0.176
plt.bar(ind,y1,width,color = '#008B45',label = 'ZSC(NT10)',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'F107_c',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = "F36_p",edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'F_fuse',edgecolor = 'black')
# plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'ACPred-Fuse',edgecolor = 'black')
plt.xticks(np.arange(5)+0.5 + 10*width, ('ACC','AUC','SP','SE','MCC'))

# plt.legend(loc="upper right",bbox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=8.05,)
plt.title('Ten-fold cross validation')
plt.text(1,0.99,'B',fontsize='xx-large')
# Independent Test
plt.ylim(0.45, 1)
# plt.savefig('F:/past.pdf',bbox_inches='tight')




ax=plt.subplot2grid((2,2), (0,0), colspan=1)

data=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\1.csv",header=None,index_col=None)
# y1 = auc(fpr, tpr)
a=data.values[:,0]
# print a
name = []
for i in range(len(a)):
#     print a[i]
    name .append(a[i])
#     name=name[0:20]
# print name
b=data.values[:,1] 
ACC = []
for i in range(len(b)):
#     print b[i]
    ACC.append(b[i])
# name = ",".join(name.split())
c=data.values[:,2] 
# name1=['100', '200', '300', '400', '500','600', '700', '800', '900', '1000'] 
MCC = []
for i in range(len(c)):
#     print c[i]
    MCC.append(c[i])
x = range(len(name))
# xk = [0,45]
plt.plot(x, ACC, marker='o', ms=3,label=u'ACC')
plt.plot(x, MCC, marker='*', ms=3,label=u'MCC')
# plt.xticks(x, name1, rotation=90, fontsize="10")
# plt.xticks(range(min(xk),max(xk)+5,5))
plt.title("SFS curves",fontsize="10")#设置剃头了
plt.xlabel('Number of features',fontsize="10")#设置x轴标签
# plt.xlim([0, x1]) #设置x轴坐标
# my_x_ticks = np.arange(0, x1, ( x1/9)/10*10)
# plt.xticks(my_x_ticks) 
# plt.xticks(arange(5), ('100', '200', '300', '400', '500'))
# plt.text(3.8,0.915,'0.912',fontsize='12')
# plt.text(17,0.925,'0.921',fontsize='12')
plt.legend(loc="lower right" )  # 让图例生效
# plt.xlim([-0.03, 46])
# plt.ylim([0.4, 0.96])
# plt.xlabel('False Positive Rate')
plt.ylabel('Performance(%)')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-37,0.837,'A',fontsize='xx-large')
# plt.legend(loc="lower right",fontsize="8"

# plt.show()
plt.savefig(r'C:\Users\Administrator\Desktop\Figure3.pdf',bbox_inches='tight')
