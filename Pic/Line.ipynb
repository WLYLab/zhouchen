# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
import pylab

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(12,8), dpi=300,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=1.08)
plt.subplot(221)
params={
# # #     'axes.labelsize': '35',
# # #     'xtick.labelsize':'27',
# # #     'ytick.labelsize':'27',
# # #     'lines.linewidth':2 ,
     'legend.fontsize': '5.5',
 
}
pylab.rcParams.update(params)

y1 = [0.4485,0.933,0.6468775]
y2 = [0.4785,0.936,0.669235385]
y3 = [0.4105,0.9455,0.622998997]
y4 = [0.425,0.9515,0.635914696]
y5 = [0.333,0.9515,0.562893862]
y6 = [0.35,0.955,0.578143581]
y7 = [0.4425,0.9345,0.74176475]
y8 = [0.483,0.9305,0.76797525]
y9 = [0.415,0.943,0.7326265]
y10 = [0.4175,0.953,0.750108625]
y11 = [0.323,0.9555,0.688144]
y12 = [0.381,0.94,0.70283275]



ind = np.arange(3)+0.5               # the x locations for the groups
width = 0.12
plt.plot(ind,y1,'-',color = '#008B45', marker='o',label = 'HUVEC_GC')  
plt.plot(ind,y2,'--',color = '#008B45', marker='*',label = 'HUVEC_RD') 
plt.plot(ind,y7,'-.',color = '#008B45', marker='s',label = 'HUVEC_GC_2-4mer+10D')  
plt.plot(ind,y8,':',color = '#008B45', marker='D',label = 'HUVEC_RD_2-4mer+10D') 
plt.plot(ind,y3,'-',color = '#36648B', marker='o',label = "K562_GC")
plt.plot(ind,y4,'--',color = '#36648B', marker='*',label = 'K562_RD')
plt.plot(ind,y9,'-.',color = '#36648B', marker='s',label = "K562_GCC_2-4mer+10D")
plt.plot(ind,y10,':',color = '#36648B', marker='D',label = 'K562_RDC_2-4mer+10D')
plt.plot(ind,y5,'-',color = '#EE8262', marker='o',label = 'NHEK_GC')
plt.plot(ind,y6,'--',color = '#EE8262', marker='*',label = 'NHEK_RD')
plt.plot(ind,y11,'-.',color = '#EE8262', marker='s',label = 'NHEK_GC_2-4mer+10D')
plt.plot(ind,y12,':',color = '#EE8262', marker='D',label = 'NHEK_RD_2-4mer+10D')
plt.xticks(ind, ('SN','SP','AUC'))

plt.legend(loc="best")
plt.title('GM12878')
plt.text(0.1,0.99,'A',fontsize='xx-large')
# Independent Test
plt.ylim(0.3, 1)

plt.subplot(222)


params={
# # #     'axes.labelsize': '35',
# # #     'xtick.labelsize':'27',
# # #     'ytick.labelsize':'27',
# # #     'lines.linewidth':2 ,
     'legend.fontsize': '5.5',
 
}
pylab.rcParams.update(params)

y1 = [0.2565,0.989,0.634691125]
y2 = [0.268,0.9845,0.640915875]
y3 = [0.372,0.988,0.696150375]
y4 = [0.38,0.986,0.699511]
y5 = [0.4455,0.9825,0.7257475]
y6 = [0.445,0.9885,0.729119375]
y7 = [0.4085,0.778,0.623003625]
y8 = [0.5535,0.7135,0.712034125]
y9 = [0.6525,0.5655,0.681783]
y10 = [0.6775,0.5775,0.70959]
y11 = [1,0,0.66748525]
y12 = [1,0,0.7138115]




ind = np.arange(3)+0.5               # the x locations for the groups
width = 0.12
plt.plot(ind,y1,'-',color = '#008B45', marker='o',label = 'GM12878_GC')  
plt.plot(ind,y2,'--',color = '#008B45', marker='*',label = 'GM12878_RD') # ind+width adjusts the left start location of the bar.
plt.plot(ind,y7,'-.',color = '#008B45', marker='s',label = 'GM12878_GC_2-4mer+10D')  
plt.plot(ind,y8,':',color = '#008B45', marker='D',label = 'GM12878_RD_2-4mer+10D') 
plt.plot(ind,y3,'-',color = '#36648B', marker='o',label = "K562_GC")
plt.plot(ind,y4,'--',color = '#36648B', marker='*',label = 'K562_RD')
plt.plot(ind,y9,'-.',color = '#36648B', marker='s',label = "K562_GCC_2-4mer+10D")
plt.plot(ind,y10,':',color = '#36648B', marker='D',label = 'K562_RDC_2-4mer+10D')
plt.plot(ind,y5,'-',color = '#EE8262', marker='o',label = 'NHEK_GC')
plt.plot(ind,y6,'--',color = '#EE8262', marker='*',label = 'NHEK_RD')
plt.plot(ind,y11,'-.',color = '#EE8262', marker='s',label = 'NHEK_GC_2-4mer+10D')
plt.plot(ind,y12,':',color = '#EE8262', marker='D',label = 'NHEK_RD_2-4mer+10D')
plt.xticks(ind, ('SN','SP','AUC'))
plt.xticks(ind, ('SN','SP','AUC'))

plt.legend(loc="best")
plt.title('HUVEC')
plt.text(0.1,0.99,'B',fontsize='xx-large')
# Independent Test
plt.ylim(0, 1)

plt.subplot(223)


params={
# # #     'axes.labelsize': '35',
# # #     'xtick.labelsize':'27',
# # #     'ytick.labelsize':'27',
# # #     'lines.linewidth':2 ,
     'legend.fontsize': '5.5',
 
}
pylab.rcParams.update(params)

y1 = [0.3735,0.9315,0.65548425]
y2 = [0.391,0.943,0.657734625]
y3 = [0.4635,0.931,0.7157105]
y4 = [0.513,0.928,0.729730625]
y5 = [0.35,0.94,0.654045625]
y6 = [0.368,0.95,0.643849]
y7 = [0.44,0.8615,0.695532625]
y8 = [0.487,0.872,0.745677]
y9 = [0.507,0.8635,0.7457305]
y10 = [0.5585,0.847,0.770019125]
y11 = [0.955,0.059,0.62730575]
y12 = [0.9685,0.0795,0.616923125]



ind = np.arange(3)+0.5               # the x locations for the groups
width = 0.12
plt.plot(ind,y1,'-',color = '#008B45', marker='o',label = 'GM12878_GC')  
plt.plot(ind,y2,'--',color = '#008B45', marker='*',label = 'GM12878_RD') # ind+width adjusts the left start location of the bar.
plt.plot(ind,y7,'-.',color = '#008B45', marker='s',label = 'GM12878_GC_2-4mer+10D')  
plt.plot(ind,y8,':',color = '#008B45', marker='D',label = 'GM12878_RD_2-4mer+10D') 
plt.plot(ind,y3,'-',color = '#36648B', marker='o',label = "HUVEC_GC")
plt.plot(ind,y4,'--',color = '#36648B', marker='*',label = 'HUVEC_RD')
plt.plot(ind,y9,'-.',color = '#36648B', marker='s',label = "HUVEC_GCC_2-4mer+10D")
plt.plot(ind,y10,':',color = '#36648B', marker='D',label = 'HUVEC_RDC_2-4mer+10D')
plt.plot(ind,y5,'-',color = '#EE8262', marker='o',label = 'NHEK_GC')
plt.plot(ind,y6,'--',color = '#EE8262', marker='*',label = 'NHEK_RD')
plt.plot(ind,y11,'-.',color = '#EE8262', marker='s',label = 'NHEK_GC_2-4mer+10D')
plt.plot(ind,y12,':',color = '#EE8262', marker='D',label = 'NHEK_RD_2-4mer+10D')
plt.xticks(ind, ('SN','SP','AUC'))

plt.legend(loc="best")
plt.title('K562')
plt.text(0.1,0.99,'C',fontsize='xx-large')
# Independent Test
plt.ylim(0, 1)

plt.subplot(224)


params={
# # #     'axes.labelsize': '35',
# # #     'xtick.labelsize':'27',
# # #     'ytick.labelsize':'27',
# # #     'lines.linewidth':2 ,
     'legend.fontsize': '5.5',
 
}
pylab.rcParams.update(params)

y1 = [0.2885,0.99,0.64340025]
y2 = [0.2915,0.9855,0.638577125]
y3 = [0.5865,0.9905,0.784909375]
y4 = [0.6065,0.991,0.805988375]
y5 = [0.363,0.9915,0.69020475]
y6 = [0.3765,0.988,0.688534125]
y7 = [1,0,0.612921]
y8 = [1,0,0.670040625]
y9 = [1,0,0.744267125]
y10 = [1,0,0.74522325]
y11 = [1,0,0.649155]
y12 = [1,0.0005,0.639867125]



ind = np.arange(3)+0.5               # the x locations for the groups
width = 0.12
plt.plot(ind,y1,'-',color = '#008B45', marker='o',label = 'GM12878_GC')  
plt.plot(ind,y2,'--',color = '#008B45', marker='*',label = 'GM12878_RD') # ind+width adjusts the left start location of the bar.
plt.plot(ind,y7,'-.',color = '#008B45', marker='s',label = 'GM12878_GC_2-4mer+10D')  
plt.plot(ind,y8,':',color = '#008B45', marker='D',label = 'GM12878_RD_2-4mer+10D') 
plt.plot(ind,y3,'-',color = '#36648B', marker='o',label = "HUVEC_GC")
plt.plot(ind,y4,'--',color = '#36648B', marker='*',label = 'HUVEC_RD')
plt.plot(ind,y9,'-.',color = '#36648B', marker='s',label = "HUVEC_GCC_2-4mer+10D")
plt.plot(ind,y10,':',color = '#36648B', marker='D',label = 'HUVEC_RDC_2-4mer+10D')
plt.plot(ind,y5,'-',color = '#EE8262', marker='o',label = 'K562_GC')
plt.plot(ind,y6,'--',color = '#EE8262', marker='*',label = 'K562_RD')
plt.plot(ind,y11,'-.',color = '#EE8262', marker='s',label = 'K562_GC_2-4mer+10D')
plt.plot(ind,y12,':',color = '#EE8262', marker='D',label = 'K562_RD_2-4mer+10D')
plt.xticks(ind, ('SN','SP','AUC'))

plt.legend(loc="best")
plt.title('NHEK')
plt.text(0.1,0.99,'D',fontsize='xx-large')
# Independent Test
plt.ylim(0, 1)
# plt.subplot(223)

# y1 = [0.774,0.866,0.683,0.558]#独立测试集
# y2 = [0.793,0.841,0.744,0.588]
# y3 = [0.768,0.866,0.671,0.547]
# y4 = [0.744, 0.805, 0.683, 0.491]
# y5 = [0.884,0.963,0.805,0.778]


# ind = np.arange(4)+2               # the x locations for the groups
# width = 0.18
# plt.bar(ind,y1,width,color = '#008B45',label = 'AntiCP_ACC',edgecolor = 'black')  
# plt.bar(ind+width,y2,width,color = '#EEC900',label = 'AntiCP_DC',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
# plt.bar(ind+2*width,y3,width,color = '#36648B',label = "Hajisharifi's_method",edgecolor = 'black')
# plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'iACP',edgecolor = 'black')
# plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'ACPred-FL',edgecolor = 'black')
# plt.xticks(np.arange(4)+0.5 + 10*width, ('ACC','SP','SE','MCC'))
# plt.text(1.15,0.99,'C',fontsize='xx-large')
# plt.legend(loc="upper right")

# plt.title('Independent test')
# # Independent Test
# plt.ylim(0.4, 1)
# plt.subplot(224)

# params={
# # # #     'axes.labelsize': '35',
# # # #     'xtick.labelsize':'27',
# # # #     'ytick.labelsize':'27',
# # # #     'lines.linewidth':2 ,
#      'legend.fontsize': '5.5',
 
# }
# pylab.rcParams.update(params)

# y1 = [0.766,0.86,0.672]
# y2 = [0.794,0.852,0.736]
# y3 = [0.772,0.864,0.68]
# y4 = [0.794,0.86,0.728]
# y5 = [0.914,0.98,0.848]
# y6 = [0.914,0.98,0.848]




# ind = np.arange(3)+2                # the x locations for the groups
# width = 0.12
# plt.bar(ind,y1,width,color = '#008B45',label = 'HUVEC_GC',edgecolor = 'black')  
# plt.bar(ind+width,y2,width,color = '#EEC900',label = 'HUVEC_RD',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
# plt.bar(ind+2*width,y3,width,color = '#36648B',label = "K562_GC",edgecolor = 'black')
# plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'K562_RD',edgecolor = 'black')
# plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'NHEK_GC',edgecolor = 'black')
# plt.bar(ind+5*width,y6,width,color = '#71C671',label = 'NHEK_RD',edgecolor = 'black')
# plt.xticks(np.arange(3)+0.5 + 15*width, ('SN','SP','AUC'))

# plt.legend(loc="upper right")
# plt.title('NHEK')
# plt.text(1.15,0.99,'D',fontsize='xx-large')
# # Independent Test
# plt.ylim(0.4, 1)
plt.savefig('C:\Users\Administrator\Desktop\New.pdf',bbox_inches='tight')
# plt.show()
