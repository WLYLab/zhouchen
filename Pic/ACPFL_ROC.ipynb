# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
import pylab

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(12,8), dpi=300,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=1.08)
plt.subplot(224)
data=pd.read_csv(u"F:/Picture/ROC/ACP/Independent_Test/Ngram1I.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#008B45',label=r'AntiCP_AAC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/Picture/ROC/ACP/Independent_Test/400D2I.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',color = '#EEC900',label=r'AntiCP_DC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/Picture/ROC/ACP/Independent_Test/Pse3I.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'y--',color = '#36648B',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)
data=pd.read_csv(u"F:/Picture/ROC/ACP/Independent_Test/GAP4I.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',color = '#EE8262',label=r'iACP(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/Picture/ROC/ACP/Independent_Test/TT5I.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',color = '#8B6914',label=r'ACPred-FL(AUC=%.2f)'%roc_auc)

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Independent test',fontsize='x-large')
# plt.text(0.4,0.53,'evaluated by NB',fontsize='x-large')
plt.text(-0.13,0.98,'D',fontsize='xx-large')
plt.legend(loc="lower right")

plt.subplot(223)


y1 = [0.776,0.918,0.633,0.575]#独立测试集
y2 = [0.796,0.918,0.673,0.61]
y3 = [0.796,0.918,0.673,0.61]
y4 = [0.786,0.939,0.633,0.6]
y5 = [0.857,0.837,0.878,0.715]


ind = np.arange(4)+2               # the x locations for the groups
width = 0.18
plt.bar(ind,y1,width,color = '#008B45',label = 'AntiCP_AAC',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'AntiCP_DC', edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = "Hajisharifi's_method",edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'iACP',edgecolor = 'black')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'ACPred-FL',edgecolor = 'black')
plt.xticks(np.arange(4)+0.5 + 10*width, ('ACC','SE','SP','MCC'))
plt.text(1.25,1.06,'C',fontsize='xx-large')
# plt.legend(loc="upper right")
plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('Independent test')
# Independent Test
plt.ylim(0.45, 1.07)

plt.subplot(222)
data=pd.read_csv(u"F:/Picture/ROC/ACP/Training_Model/Ngram1.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#008B45',label=r'AntiCP_AAC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/Picture/ROC/ACP/Training_Model/400D2.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',color = '#EEC900',label=r'AntiCP_DC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/Picture/ROC/ACP/Training_Model/Pse3.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'y--',color = '#36648B',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)
data=pd.read_csv(u"F:/Picture/ROC/ACP/Training_Model/GAP4.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',color = '#EE8262',label=r'iACP(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/Picture/ROC/ACP/Training_Model/FT5.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',color = '#8B6914',label=r'ACPred-FL(AUC=%.2f)'%roc_auc)

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
# plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.13,0.98,'B',fontsize='xx-large')
plt.legend(loc="lower right")
plt.subplot(221)

params={
# # #     'axes.labelsize': '35',
# # #     'xtick.labelsize':'27',
# # #     'ytick.labelsize':'27',
# # #     'lines.linewidth':2 ,
     'legend.fontsize': '9',
 
}
pylab.rcParams.update(params)

y1 = [0.832,0.81,0.854,0.664]
y2 = [0.832,0.805,0.859,0.664]
y3 = [0.829,0.805,0.854,0.659]
y4 = [0.844,0.839,0.849,0.688]
y5 = [0.9,0.888,0.912,0.8]

ind = np.arange(4)+2                # the x locations for the groups
width = 0.18
plt.bar(ind,y1,width,color = '#008B45',label = 'AntiCP_AAC',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'AntiCP_DC',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = "Hajisharifi's_method",edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'iACP',edgecolor = 'black')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'ACPred-FL',edgecolor = 'black')
plt.xticks(np.arange(4)+0.5 + 10*width, ('ACC','SE','SP','MCC'))

# plt.legend(loc="upper right",bbox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('Ten-fold cross validation')
plt.text(1.25,1.06,'A',fontsize='xx-large')
# Independent Test
plt.ylim(0.45, 1.07)
plt.savefig('F:/new.pdf',bbox_inches='tight')
# plt.show()

# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
import pylab

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(12,8), dpi=300,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=1.08)
# plt.subplot(224)
# data=pd.read_csv(r"C:\Users\Administrator\Desktop\picture\ACP\1\400D_RF_predict.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'r-.',color = '#008B45',label=r'AntiCP_DC(AUC=%.2f)'%roc_auc)
# data=pd.read_csv(u"C:\Users\Administrator\Desktop\picture\ACP\1\PseTrain_RF_predict.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'b-.',color = '#EEC900',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)
# data=pd.read_csv(u"FC:\Users\Administrator\Desktop\picture\ACP\1\ACPFL_RF_predict.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'y--',color = '#36648B',label=r"ACPred-FL(AUC=%.2f)"%roc_auc)
# data=pd.read_csv(u"C:\Users\Administrator\Desktop\picture\ACP\1\PEP_RF_predict.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'g--',color = '#EE8262',label=r'PEP-Suite(AUC=%.2f)'%roc_auc)
# data=pd.read_csv(u"C:\Users\Administrator\Desktop\picture\ACP\1\FT174_RF_predict.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'r-',color = '#8B6914',label=r'ACPred-Fuse(AUC=%.2f)'%roc_auc)

# plt.xlim([0, 1])
# plt.ylim([0, 1])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.text(0.4,0.6,'Independent test',fontsize='x-large')
# # plt.text(0.4,0.53,'evaluated by NB',fontsize='x-large')
# plt.text(-0.13,0.98,'D',fontsize='xx-large')
# plt.legend(loc="lower right")

plt.subplot(223)


y1 = [0.882,0.826,0.683,0.830]#独立测试集
y2 = [0.879,0.884,0.695,0.855]
y3 = [0.853,0.858,0.695,0.851]
y4 = [0.899, 0.906, 0.683, 0.861]
y5 = [0.890,0.895,0.720,0.868]


ind = np.arange(4)+2               # the x locations for the groups
width = 0.18
plt.bar(ind,y1,width,color = '#008B45',label = 'AntiCP_DC',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'Hajisharifi’s method',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = "ACPred-FL",edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'PEP-Suite',edgecolor = 'black')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'ACPred-Fuse',edgecolor = 'black')
plt.xticks(np.arange(4)+0.5 + 10*width, ('ACC','SP','SE','AUC'))
lt.text(1.15,0.99,'C',fontsize='xx-large')
# plt.legend(loc="upper right")
plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('Independent test')
# Independent Test
plt.ylim(0.45, 1)

# plt.subplot(222)
# data=pd.read_csv(u"C:\Users\Administrator\Desktop\picture\ACP\1\N-gram(N=1).csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'r-.',color='#008B45',label=r'AntiCP_AAC(AUC=%.2f)'%roc_auc)
# data=pd.read_csv(u"C:\Users\Administrator\Desktop\picture\ACP\1\g-gaps(g=0)400.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'b-.',color = '#EEC900',label=r'AntiCP_DC(AUC=%.2f)'%roc_auc)
# data=pd.read_csv(u"C:\Users\Administrator\Desktop\picture\ACP\1\Pse-in-one(pse).csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'y--',color = '#36648B',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)
# data=pd.read_csv(u"FC:\Users\Administrator\Desktop\picture\ACP\1\g-gaps(g=1)126.csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'g--',color = '#EE8262',label=r'iACP(AUC=%.2f)'%roc_auc)
# data=pd.read_csv(u"C:\Users\Administrator\Desktop\picture\ACP\1\AcPred-RFL(5).csv",header=None,index_col=None)
# fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
# roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,'r-',color = '#8B6914',label=r'ACPred-FL(AUC=%.2f)'%roc_auc)

# plt.xlim([0, 1])
# plt.ylim([0, 1])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
# # plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
# plt.text(-0.13,0.98,'B',fontsize='xx-large')
# plt.legend(loc="lower right")
plt.subplot(221)

params={
# # #     'axes.labelsize': '35',
# # #     'xtick.labelsize':'27',
# # #     'ytick.labelsize':'27',
# # #     'lines.linewidth':2 ,
     'legend.fontsize': '9',
 
}
pylab.rcParams.update(params)

y1 = [0.746,0.776,0.716,0.825]
y2 = [0.754,0.836,0.672,0.831]
y3 = [0.780,0.844,0.716,0.846]
y4 = [0.804,0.880,0.728,0.860]
y5 = [0.824,0.876,0.772,0.882]






ind = np.arange(4)+2                # the x locations for the groups
width = 0.18
plt.bar(ind,y1,width,color = '#008B45',label = 'AntiCP_DC',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'Hajisharifi’s method',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = "ACPred-FL",edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'PEP-Suite',edgecolor = 'black')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'ACPred-Fuse',edgecolor = 'black')
plt.xticks(np.arange(4)+0.5 + 10*width, ('ACC','SP','SE','AUC'))

# plt.legend(loc="upper right",bbox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('Ten-fold cross validation')
plt.text(1.15,0.99,'A',fontsize='xx-large')
# Independent Test
plt.ylim(0.45, 1)
plt.savefig('F:/past.pdf',bbox_inches='tight')
# plt.show()
