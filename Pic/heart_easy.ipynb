# %%
# example program
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab as pl
#data preprocessing
# iris = sns.load_dataset("iris")
# iris =sns.load_dataset(r"C:\Users\Administrator\Desktop\r.txt")
# print iris
# iris.loc(["sepal_length","species"])
# data=iris[(iris.species=="setosa") | (iris.species=="virginica")]
# data=data[["sepal_length","species"]]
# print iris
# data.fillna(0.1)
# data["species"]=1
# print data
# data=data.values
# print data
# data=data[0:20]
# print data
data=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\mRMRc_all4.csv")
data1=data[0:41]
data2=data[41:82]
data3=data[82:123]
data4=data[123:164]
#  data =sns.load_dataset(r"C:\Users\Administrator\Desktop\r.txt")
# print data.values
dataf2=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim2\FTc_all4.csv",header=None,index_col=None)
e=dataf2.values[:,0] 
ACCp = []
for i in range(0,41):
#     print b[i]
    ACCp.append(e[i])
# name = ",".join(name.split())

data1.index=ACCp

ACCp2 = []
for i in range(41,82):
#     print b[i]
    ACCp2.append(e[i])
# name = ",".join(name.split())

data2.index=ACCp2

ACCp3 = []
for i in range(82,123):
#     print b[i]
    ACCp3.append(e[i])
# name = ",".join(name.split())

data3.index=ACCp3

ACCp4 = []
for i in range(123,164):
#     print b[i]
    ACCp4.append(e[i])
# name = ",".join(name.split())

data4.index=ACCp4
#define a panel with size (12,12) and 300 dpi
plt.figure(figsize=(8,8), dpi=300,facecolor=(1, 1, 1))
plt.subplots_adjust(wspace =1.2, hspace =0.42)#调整子图间距

#adjust distrances of subplots
# plt.subplots_adjust(wspace =0.3, hspace =0.15)

#plot multi sub figures into one figure
# cmap = sns.cubehelix_palette(start = 1.5, rot = 3, gamma=0.8, as_cmap = True)#调色板

# grid_kws = {"height_ratios": (.9, .05), "hspace": .2}
ax=plt.subplot2grid((1,40), (0,0), colspan=9)

# f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws)
ax=sns.heatmap(data1,linewidths = 0.5,cmap="Blues",  center=0.0,vmax=0.01, vmin=0,
               xticklabels=1, yticklabels=1,cbar=False,square =True,cbar_kws={"orientation": "horizontal"}) 
#, ax=ax,cbar_ax=cbar_ax,cbar_kws={"orientation": "horizontal"}
# color: rainbow YlOrRd
ax.set_xlabel('')

plt.yticks(Rotation=0,fontsize=10)
# plt.xticks(Rotation=90,fontsize=3)
ax.xaxis.tick_top()
plt.xticks(Rotation=90,fontsize=10)
# plt.ylabel("Feature",fontsize=5)
# plt.xlabel("Peptides",fontsize=5)
#show figure 

ax=plt.subplot2grid((1,40), (0,10), colspan=9)

# f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws)
ax=sns.heatmap(data2,linewidths = 0.5,cmap="Blues", center=0.0,vmax=0.01, vmin=0,
               xticklabels=1, yticklabels=1,cbar=False,square =True,cbar_kws={"orientation": "horizontal"}) 
#, ax=ax,cbar_ax=cbar_ax,cbar_kws={"orientation": "horizontal"}
# color: rainbow YlOrRd
ax.set_xlabel('')

plt.yticks(Rotation=0,fontsize=10)
# plt.xticks(Rotation=90,fontsize=3)
ax.xaxis.tick_top()
plt.xticks(Rotation=90,fontsize=10)
# plt.ylabel("Feature",fontsize=5)
# plt.xlabel("Peptides",fontsize=5)
#show figures

ax=plt.subplot2grid((1,40), (0,19), colspan=9)

# f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws)
ax=sns.heatmap(data3,linewidths = 0.5,cmap="Blues", center=0.0,vmax=0.01, vmin=0,
               xticklabels=1, yticklabels=1,cbar=False,square =True,cbar_kws={"orientation": "horizontal"}) 
#, ax=ax,cbar_ax=cbar_ax,cbar_kws={"orientation": "horizontal"}
# color: rainbow YlOrRd
ax.set_xlabel('')

plt.yticks(Rotation=0,fontsize=10)
# plt.xticks(Rotation=90,fontsize=3)
ax.xaxis.tick_top()
plt.xticks(Rotation=90,fontsize=10)
# plt.ylabel("Feature",fontsize=5)
# plt.xlabel("Peptides",fontsize=5)
#show figures


ax=plt.subplot2grid((1,40), (0,26), colspan=11)

# f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws)
ax=sns.heatmap(data4,linewidths = 0.5,cmap="Blues", center=0.0,vmax=0.01, vmin=0,square =True,
               xticklabels=1, yticklabels=1) 
#, ax=ax,cbar_ax=cbar_ax,cbar_kws={"orientation": "horizontal"}
# color: rainbow YlOrRd
ax.set_xlabel('')

plt.yticks(Rotation=0,fontsize=10)
# plt.xticks(Rotation=90,fontsize=3)
ax.xaxis.tick_top()
plt.xticks(Rotation=90,fontsize=10)
# plt.ylabel("Feature",fontsize=5)
# plt.xlabel("Peptides",fontsize=5)
#show figure


# plt.show()
plt.savefig('C:\Users\Administrator\Desktop\heart.pdf',bbox_inches='tight')
