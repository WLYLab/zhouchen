# %%
# import necessary packages and these packages must be installed before. you can use command "install.packages("XXXXX")", where XXXXX means package name
# install.packages("cowplot")
# install.packages("ggplot2")
# install.packages("Rmisc")
library(cowplot)
library(ggplot2)
library(Rmisc)

#data preprocessing
data=subset(iris, Species=="setosa" |Species=="virginica",select=c("Species","Sepal.Length"))
data
#the function of drawing boxplot
boxplot_function<-function(data,arg1,arg2){
    pp<-ggplot(data,aes(x=arg1,y=arg2,fill=Species))+ stat_boxplot(geom = "errorbar",width=0.3)+
geom_boxplot(show.legend = FALSE )+scale_fill_manual(values = c("#6699cc", "#CB9898"))+
theme_bw() +theme( legend.position = "none",plot.title=element_text( size=9, face="bold", colour="black"),
axis.title.x=element_blank(),
axis.title.y=element_text( size=9, face="bold",angle=90, colour="black"),
axis.text.x=element_text( size=9, face="bold",colour="black"),legend.title=element_text( size=9, face="bold",colour="black"),
axis.text.y=element_text( size=9, face="bold",colour="black"),legend.text=element_text( size=9, face="bold",colour="black"),
axis.ticks=element_line(colour = "black"),
axis.line=element_line(colour="black"))
 return(pp)
}

#the use of defined function, where data stands for data used for plotting, data$Species and data$Length are used as X and Y axis data for drawing
p<-boxplot_function(data,data$Species,data$Sepal.Length)

#plot multi sub figures into one figure
pp=plot_grid(p,p,p,p,p,p,p,p,p,labels = c("A", "B","C","D","E","F","G","H","I"),ncol = 3,nrow = 3 )
pp
# ggsave("test_boxplot_R.tiff",pp)
# Out:
#     Species   Sepal.Length
# 1   setosa    5.1
# 2   setosa    4.9
# 3   setosa    4.7
# 4   setosa    4.6
# 5   setosa    5.0
# 6   setosa    5.4
# 7   setosa    4.6
# 8   setosa    5.0
# 9   setosa    4.4
# 10  setosa    4.9
# 11  setosa    5.4
# 12  setosa    4.8
# 13  setosa    4.8
# 14  setosa    4.3
# 15  setosa    5.8
# 16  setosa    5.7
# 17  setosa    5.4
# 18  setosa    5.1
# 19  setosa    5.7
# 20  setosa    5.1
# 21  setosa    5.4
# 22  setosa    5.1
# 23  setosa    4.6
# 24  setosa    5.1
# 25  setosa    4.8
# 26  setosa    5.0
# 27  setosa    5.0
# 28  setosa    5.2
# 29  setosa    5.2
# 30  setosa    4.7
# ... ...       ...
# 121 virginica 6.9
# 122 virginica 5.6
# 123 virginica 7.7
# 124 virginica 6.3
# 125 virginica 6.7
# 126 virginica 7.2
# 127 virginica 6.2
# 128 virginica 6.1
# 129 virginica 6.4
# 130 virginica 7.2
# 131 virginica 7.4
# 132 virginica 7.9
# 133 virginica 6.4
# 134 virginica 6.3
# 135 virginica 6.1
# 136 virginica 7.7
# 137 virginica 6.3
# 138 virginica 6.4
# 139 virginica 6.0
# 140 virginica 6.9
# 141 virginica 6.7
# 142 virginica 6.9
# 143 virginica 5.8
# 144 virginica 6.8
# 145 virginica 6.7
# 146 virginica 6.7
# 147 virginica 6.3
# 148 virginica 6.5
# 149 virginica 6.2
# 150 virginica 5.9
# plot without title
