# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(12,12), dpi=300,facecolor=(1, 1, 1))
plt.subplot(321)
data=pd.read_csv(u"F:/draw_protein/NB_Independent_Test/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(ROC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/NB_Independent_Test/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(ROC=%f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/NB_Independent_Test/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(ROC=%f)'%roc_auc)

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Independent Test',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by NB',fontsize='x-large')
plt.text(-0.125,0.98,'A',fontsize='xx-large')
plt.legend(loc="lower right")

plt.subplot(322)
data=pd.read_csv(u"F:/draw_protein/NB_TrainingModel/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(ROC=%f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/NB_TrainingModel/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(ROC=%f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/NB_TrainingModel/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(ROC=%f)'%roc_auc)





plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Cross Validation Test',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by NB',fontsize='x-large')
plt.text(-0.125,0.98,'B',fontsize='xx-large')
plt.legend(loc="lower right")
plt.subplot(323)
data=pd.read_csv(u"F:/draw_protein/RF_Independent_Test/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(ROC=%f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/RF_Independent_Test/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(ROC=%f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/RF_Independent_Test/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(ROC=%f)'%roc_auc)

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Independent Test',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.125,0.98,'C',fontsize='xx-large')
plt.legend(loc="lower right")
plt.subplot(324)
data=pd.read_csv(u"F:/draw_protein/RF_Training_Model/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(ROC=%f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/RF_Training_Model/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(ROC=%f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/RF_Training_Model/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(ROC=%f)'%roc_auc)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Cross Validation',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.125,0.98,'D',fontsize='xx-large')

plt.legend(loc="lower right")
plt.subplot(325)
data=pd.read_csv(u"F:/draw_protein/SVM_Independent_Test/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(ROC=%f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/SVM_Independent_Test/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(ROC=%f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/SVM_Independent_Test/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(ROC=%f)'%roc_auc)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Independent Test',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by SVM',fontsize='x-large')
plt.text(-0.125,0.98,'E',fontsize='xx-large')
plt.legend(loc="lower right")
plt.subplot(326)
data=pd.read_csv(u"F:/draw_protein/SVM_Training_Model/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(ROC=%f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/SVM_Training_Model/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(ROC=%f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/SVM_Training_Model/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(ROC=%f)'%roc_auc)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Cross validation Test',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by SVM',fontsize='x-large')
plt.text(-0.125,0.98,'F',fontsize='xx-large')
plt.legend(loc="lower right")
# plt.legend(loc="lower right")
plt.savefig('F:/article/protein(修正1).tif',dpi=300)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-4adf797a8f49> in <module>()
#      15 plt.figure(figsize=(12,12), dpi=300,facecolor=(1, 1, 1))
#      16 plt.subplot(321)
# ---> 17 data=pd.read_csv(u"F:/draw_protein/NB_Independent_Test/NB_based_feature.csv",header=None,index_col=None)
#      18 fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
#      19 roc_auc = auc(fpr, tpr)
#
# ...

# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(12,12), dpi=300,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=1.08)
plt.subplot(326)
data=pd.read_csv(u"F:/draw_protein/NB_Independent_Test/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/NB_Independent_Test/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/NB_Independent_Test/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(AUC=%.2f)'%roc_auc)

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Independent test',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by NB',fontsize='x-large')
plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.legend(loc="lower right")

plt.subplot(325)
data=pd.read_csv(u"F:/draw_protein/NB_TrainingModel/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/NB_TrainingModel/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/NB_TrainingModel/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(AUC=%.2f)'%roc_auc)





plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Cross validation test',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by NB',fontsize='x-large')
plt.text(-0.13,0.98,'E',fontsize='xx-large')
plt.legend(loc="lower right")
plt.subplot(324)
data=pd.read_csv(u"F:/draw_protein/RF_Independent_Test/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/RF_Independent_Test/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/RF_Independent_Test/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(AUC=%.2f)'%roc_auc)

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Independent test',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.13,0.98,'D',fontsize='xx-large')
plt.legend(loc="lower right")
plt.subplot(323)
data=pd.read_csv(u"F:/draw_protein/RF_Training_Model/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/RF_Training_Model/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/RF_Training_Model/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(AUC=%.2f)'%roc_auc)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Cross validation test',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.13,0.98,'C',fontsize='xx-large')

plt.legend(loc="lower right")
plt.subplot(322)
data=pd.read_csv(u"F:/draw_protein/SVM_Independent_Test/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/SVM_Independent_Test/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/SVM_Independent_Test/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(AUC=%.2f)'%roc_auc)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Independent test',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by SVM',fontsize='x-large')
plt.text(-0.13,0.98,'B',fontsize='xx-large')
plt.legend(loc="lower right")
plt.subplot(321)
data=pd.read_csv(u"F:/draw_protein/SVM_Training_Model/NB_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label=r'$FV_{NB}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/SVM_Training_Model/RF_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label=r'$FV_{RF}$(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/SVM_Training_Model/SVM_based_feature.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',label=r'$FV_{SVM}$(AUC=%.2f)'%roc_auc)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Cross validation test',fontsize='x-large')
plt.text(0.4,0.53,'evaluated by SVM',fontsize='x-large')
plt.text(-0.13,0.98,'A',fontsize='xx-large')
plt.legend(loc="lower right")
# plt.legend(loc="lower right")
plt.savefig('F:/article/protein(revised)2.tif',bbox_inches='tight')

# fig = matplotlib.pyplot.gcf()
# fig.set_size_inches(12, 12)
# fig.savefig('F:/article/test2png.tif', dpi=300)
# plt.show()

# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
import pylab

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(12,8), dpi=300,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=1.08)
plt.subplot(224)
data=pd.read_csv(u"F:/draw_protein/ROC/Independent_Test/N-gram(N=1).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#008B45',label=r'AntiCP_ACC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Independent_Test/g-gaps(g=0)400.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',color = '#EEC900',label=r'AntiCP_DC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Independent_Test/Pse-in-one(pse).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'y--',color = '#36648B',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Independent_Test/g-gaps(g=1)126.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',color = '#EE8262',label=r'iACP(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Independent_Test/Acpred-RFL(5).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',color = '#8B6914',label=r'ACPred-FL(AUC=%.2f)'%roc_auc)

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Independent test',fontsize='x-large')
# plt.text(0.4,0.53,'evaluated by NB',fontsize='x-large')
plt.text(-0.13,0.98,'D',fontsize='xx-large')
plt.legend(loc="lower right")

plt.subplot(223)


y1 = [0.774,0.866,0.683,0.558]#独立测试集
y2 = [0.793,0.841,0.744,0.588]
y3 = [0.768,0.866,0.671,0.547]
y4 = [0.744, 0.805, 0.683, 0.491]
y5 = [0.884,0.963,0.805,0.778]


ind = np.arange(4)+2               # the x locations for the groups
width = 0.18
plt.bar(ind,y1,width,color = '#008B45',label = 'AntiCP_ACC',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'AntiCP_DC',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = "Hajisharifi's_method",edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'iACP',edgecolor = 'black')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'ACPred-FL',edgecolor = 'black')
plt.xticks(np.arange(4)+0.5 + 10*width, ('ACC','SP','SE','MCC'))
plt.text(1.15,0.99,'C',fontsize='xx-large')
plt.legend(loc="upper right")

plt.title('Independent test')
# Independent Test
plt.ylim(0.4, 1)

plt.subplot(222)
data=pd.read_csv(u"F:/draw_protein/ROC/Training_Model/N-gram(N=1).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color='#008B45',label=r'AntiCP_ACC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Training_Model/g-gaps(g=0)400.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',color = '#EEC900',label=r'AntiCP_DC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Training_Model/Pse-in-one(pse).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'y--',color = '#36648B',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Training_Model/g-gaps(g=1)126.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',color = '#EE8262',label=r'iACP(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Training_Model/AcPred-RFL(5).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',color = '#8B6914',label=r'ACPred-FL(AUC=%.2f)'%roc_auc)

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
# plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.13,0.98,'B',fontsize='xx-large')
plt.legend(loc="lower right")
plt.subplot(221)

params={
# # #     'axes.labelsize': '35',
# # #     'xtick.labelsize':'27',
# # #     'ytick.labelsize':'27',
# # #     'lines.linewidth':2 ,
     'legend.fontsize': '5.5',
 
}
pylab.rcParams.update(params)

y1 = [0.766,0.86,0.672,0.542]
y2 = [0.794,0.852,0.736,0.592]
y3 = [0.772,0.864,0.68,0.553]
y4 = [0.794,0.86,0.728,0.593]
y5 = [0.914,0.98,0.848,0.835]






ind = np.arange(4)+2                # the x locations for the groups
width = 0.18
plt.bar(ind,y1,width,color = '#008B45',label = 'AntiCP_ACC',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'AntiCP_DC',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = "Hajisharifi's_method",edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'iACP',edgecolor = 'black')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'ACPred-FL',edgecolor = 'black')
plt.xticks(np.arange(4)+0.5 + 10*width, ('ACC','SP','SE','MCC'))

plt.legend(loc="upper right")
plt.title('Ten-fold cross validation')
plt.text(1.15,0.99,'A',fontsize='xx-large')
# Independent Test
plt.ylim(0.4, 1)
# plt.savefig('F:/draw_protein/hist_ROC.tif',bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import mlab
from matplotlib import rcParams
import scipy.io
import matplotlib.pylab as pylab
import matplotlib.ticker as mtick
params={
#     'axes.labelsize': '35',
#     'xtick.labelsize':'27',
#     'ytick.labelsize':'27',
#     'lines.linewidth':2 ,
    'legend.fontsize': '23',
 
}
pylab.rcParams.update(params)

y1 = [0.766,0.542,0.672,0.86]
y2 = [0.794,0.592,0.736,0.852]
y3 = [0.772,0.553,0.68,0.864]
y4 = [0.794,0.593,0.728,0.86]
y5 = [0.914,0.835,0.848,0.98]

# y1 = [0.774,0.558,0.683,0.866]//独立测试集
# y2 = [0.793,0.588,0.744,0.841]
# y3 = [0.768,0.547,0.671,0.866]
# y4 = [0.744,0.491,0.683,0.805]
# y5 = [0.884,0.778,0.805,0.963]




ind = np.arange(4)                # the x locations for the groups
width = 0.15
plt.bar(ind,y1,width,color = '#008B45',label = 'AntiCP_ACC')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = ''AntiCP_DC') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = 'Hajisharifi's_method')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'iACP')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'ACPred-FL')
plt.xticks(np.arange(5) + 2.5*width, ('ACC','SP','SE','MCC'))
plt.legend(loc="upper right")

plt.title('Training Model (10-fold cross validation)')
# Independent Test
plt.ylim(0.5, 1)




plt.show()
# Out:
#   File "<ipython-input-2-a7a4101cba72>", line 36
#     plt.bar(ind+width,y2,width,color = '#EEC900',label = ''AntiCP_DC') # ind+width adjusts the left start location of the bar.
#                                                                    ^
# SyntaxError: invalid syntax

# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
import pylab

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(12,8), dpi=300,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=1.08)
plt.subplot(224)
data=pd.read_csv(u"F:/draw_protein/ROC/Independent_Test/N-gram(N=1).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color = '#008B45',label=r'AntiCP_ACC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Independent_Test/g-gaps(g=0)400.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',color = '#EEC900',label=r'AntiCP_DC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Independent_Test/Pse-in-one(pse).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'y--',color = '#36648B',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Independent_Test/g-gaps(g=1)126.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',color = '#EE8262',label=r'iACP(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Independent_Test/Acpred-RFL(5).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',color = '#8B6914',label=r'ACPred-FL(AUC=%.2f)'%roc_auc)

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Independent test',fontsize='x-large')
# plt.text(0.4,0.53,'evaluated by NB',fontsize='x-large')
plt.text(-0.13,0.98,'D',fontsize='xx-large')
plt.legend(loc="lower right")

plt.subplot(223)


y1 = [0.774,0.866,0.683,0.558]#独立测试集
y2 = [0.793,0.841,0.744,0.588]
y3 = [0.768,0.866,0.671,0.547]
y4 = [0.744, 0.805, 0.683, 0.491]
y5 = [0.884,0.963,0.805,0.778]


ind = np.arange(4)+2               # the x locations for the groups
width = 0.18
plt.bar(ind,y1,width,color = '#008B45',label = 'AntiCP_ACC',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'AntiCP_DC',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = "Hajisharifi's_method",edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'iACP',edgecolor = 'black')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'ACPred-FL',edgecolor = 'black')
plt.xticks(np.arange(4)+0.5 + 10*width, ('ACC','SP','SE','MCC'))
plt.text(1.15,0.99,'C',fontsize='xx-large')
# plt.legend(loc="upper right")
plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('Independent test')
# Independent Test
plt.ylim(0.45, 1)

plt.subplot(222)
data=pd.read_csv(u"F:/draw_protein/ROC/Training_Model/N-gram(N=1).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-.',color='#008B45',label=r'AntiCP_ACC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Training_Model/g-gaps(g=0)400.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',color = '#EEC900',label=r'AntiCP_DC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Training_Model/Pse-in-one(pse).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'y--',color = '#36648B',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Training_Model/g-gaps(g=1)126.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'g--',color = '#EE8262',label=r'iACP(AUC=%.2f)'%roc_auc)
data=pd.read_csv(u"F:/draw_protein/ROC/Training_Model/AcPred-RFL(5).csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',color = '#8B6914',label=r'ACPred-FL(AUC=%.2f)'%roc_auc)

plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
# plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.13,0.98,'B',fontsize='xx-large')
plt.legend(loc="lower right")
plt.subplot(221)

params={
# # #     'axes.labelsize': '35',
# # #     'xtick.labelsize':'27',l
# # #     'ytick.labelsize':'27',
# # #     'lines.linewidth':2 ,
     'legend.fontsize': '9',
 
}
pylab.rcParams.update(params)

y1 = [0.766,0.86,0.672,0.542]
y2 = [0.794,0.852,0.736,0.592]
y3 = [0.772,0.864,0.68,0.553]
y4 = [0.794,0.86,0.728,0.593]
y5 = [0.914,0.98,0.848,0.835]






ind = np.arange(4)+2                # the x locations for the groups
width = 0.18
plt.bar(ind,y1,width,color = '#008B45',label = 'AntiCP_ACC',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'AntiCP_DC',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = "Hajisharifi's_method",edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'iACP',edgecolor = 'black')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'ACPred-FL',edgecolor = 'black')
plt.xticks(np.arange(4)+0.5 + 10*width, ('ACC','SP','SE','MCC'))

# plt.legend(loc="upper right",bbox_to_anchor=(1, 0.5))
# plt.legend(loc="upper right",ncol=2)
plt.legend(loc="upper right",ncol=2,handletextpad=0.2,fontsize=9.05,columnspacing=-4)
plt.title('Ten-fold cross validation')
plt.text(1.15,0.99,'A',fontsize='xx-large')
# Independent Test
plt.ylim(0.45, 1)
plt.savefig('F:/draw_protein/hist_ROC2.pdf',bbox_inches='tight')
# plt.show()
