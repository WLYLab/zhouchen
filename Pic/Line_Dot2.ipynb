# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

plt.figure(figsize=(10,5), dpi=200,facecolor=(1, 1, 1))
data=pd.read_csv(r"C:\Users\Administrator\Desktop\\Peptides_optim\Anti-angiogenic_Peptides\fastadata\Result_FT80Anti-angiogenic_Peptides.csv",header=None,index_col=None)
# y1 = auc(fpr, tpr)
a=data.values[:,1]
name = []
for i in range(len(a)):
#     print a[i]
    name .append(a[i])
    
b=data.values[:,2] 
ACC1 = []
for i in range(len(b)):
#     print b[i]
    ACC1.append(b[i])
# name = ",".join(name.split())
c=data.values[:,6] 

MCC1 = []
for i in range(len(c)):
#     print c[i]
    MCC1.append(c[i])
# y1 = y.replace(' ', '，')
# print  ACCc
# x = range(len(y1))
data2=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim\Anti-bacterial_Peptides\fastadata\Result_FT92Anti-bacterial_Peptides.csv",header=None,index_col=None)
b2=data2.values[:,2] 
ACC2 = []
for i in range(len(b2)):
#     print b[i]
    ACC2.append(b2[i])
# name = ",".join(name.split())
c2=data2.values[:,6] 

MCC2 = []
for i in range(len(c2)):
#     print c[i]
    MCC2.append(c2[i])
    
    x = range(len(name))

# plt.figure(figsize=(10,5), dpi=200,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=108)
# ax=plt.subplot(222)

ax=plt.subplot2grid((2,2), (0,0), colspan=1)
# ax=plt.subplot(221)
plt.plot(x, ACC1, marker='o', ms=3,label=u'ACC-FT(80)')
plt.plot(x, MCC1, marker='*', ms=3,label=u'MCC-FT(80)')
plt.xticks(x, name, rotation=90, fontsize="6")
# plt.text(3.8,0.915,'0.912',fontsize='12')
# plt.text(17,0.925,'0.921',fontsize='12')
plt.legend(loc="lower right" )  # 让图例生效

# plt.xlim([-0.03, 46])
plt.ylim([0.4, 0.96])
# plt.xlabel('False Positive Rate')
plt.ylabel('Performance(%)')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-10,0.935,'A',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")


ax=plt.subplot2grid((2,2), (0,1), colspan=1)
plt.plot(x, ACC2, marker='o', ms=3,label=u'ACC-FT(92)')
plt.plot(x, MCC2, marker='*', ms=3,label=u'MCC-FT(92)')
plt.xticks(x, name, rotation=90, fontsize="6")
plt.legend(loc="lower right" )  # 让图例生效

# plt.xlim([-0.03, 46])
plt.ylim([0.4, 0.96])
# plt.xlabel('False Positive Rate')
plt.ylabel('Performance(%)')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-10,0.935,'B',fontsize='xx-large')
# plt.text(3.8,0.832,'0.825',fontsize='12')
# plt.text(17,0.849,'0.842',fontsize='12')
plt.legend(loc="lower right",fontsize="8")

data=pd.read_csv(r"C:\Users\Administrator\Desktop\\Peptides_optim\Anti-angiogenic_Peptides\fastadata\Result_FT80Anti-angiogenic_Peptides.csv",header=None,index_col=None)
# y1 = auc(fpr, tpr)
a=data.values[:,1]
name = []
for i in range(len(a)):
#     print a[i]
    name .append(a[i])
    
b=data.values[:,2] 
ACC1 = []
for i in range(len(b)):
#     print b[i]
    ACC1.append(b[i])
# name = ",".join(name.split())
c=data.values[:,6] 

MCC1 = []
for i in range(len(c)):
#     print c[i]
    MCC1.append(c[i])
# y1 = y.replace(' ', '，')
# print  ACCc
# x = range(len(y1))
data2=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim\Anti-bacterial_Peptides\fastadata\Result_FT92Anti-bacterial_Peptides.csv",header=None,index_col=None)
b2=data2.values[:,2] 
ACC2 = []
for i in range(len(b2)):
#     print b[i]
    ACC2.append(b2[i])
# name = ",".join(name.split())
c2=data2.values[:,6] 

MCC2 = []
for i in range(len(c2)):
#     print c[i]
    MCC2.append(c2[i])
    
    x = range(len(name))

# plt.figure(figsize=(10,5), dpi=200,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=108)
# ax=plt.subplot(222)

ax=plt.subplot2grid((2,2), (1,0), colspan=1)
# ax=plt.subplot(221)
plt.plot(x, ACC1, marker='o', ms=3,label=u'ACC-FT(80)')
plt.plot(x, MCC1, marker='*', ms=3,label=u'MCC-FT(80)')
plt.xticks(x, name, rotation=90, fontsize="6")
# plt.text(3.8,0.915,'0.912',fontsize='12')
# plt.text(17,0.925,'0.921',fontsize='12')
plt.legend(loc="lower right" )  # 让图例生效

# plt.xlim([-0.03, 46])
plt.ylim([0.4, 0.96])
# plt.xlabel('False Positive Rate')
plt.ylabel('Performance(%)')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-10,0.935,'C',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")


ax=plt.subplot2grid((2,2), (1,1), colspan=1)
plt.plot(x, ACC2, marker='o', ms=3,label=u'ACC-FT(92)')
plt.plot(x, MCC2, marker='*', ms=3,label=u'MCC-FT(92)')
plt.xticks(x, name, rotation=90, fontsize="6")
plt.legend(loc="lower right" )  # 让图例生效

# plt.xlim([-0.03, 46])
plt.ylim([0.4, 0.96])
# plt.xlabel('False Positive Rate')
plt.ylabel('Performance(%)')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-10,0.935,'D',fontsize='xx-large')
# plt.text(3.8,0.832,'0.825',fontsize='12')
# plt.text(17,0.849,'0.842',fontsize='12')
plt.legend(loc="lower right",fontsize="8")

plt.figure(figsize=(10,5), dpi=200,facecolor=(1, 1, 1))
data=pd.read_csv(r"C:\Users\Administrator\Desktop\\Peptides_optim\Anti-angiogenic_Peptides\fastadata\Result_FT80Anti-angiogenic_Peptides.csv",header=None,index_col=None)
# y1 = auc(fpr, tpr)
a=data.values[:,1]
name = []
for i in range(len(a)):
#     print a[i]
    name .append(a[i])
    
b=data.values[:,2] 
ACC1 = []
for i in range(len(b)):
#     print b[i]
    ACC1.append(b[i])
# name = ",".join(name.split())
c=data.values[:,6] 

MCC1 = []
for i in range(len(c)):
#     print c[i]
    MCC1.append(c[i])
# y1 = y.replace(' ', '，')
# print  ACCc
# x = range(len(y1))
data2=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim\Anti-bacterial_Peptides\fastadata\Result_FT92Anti-bacterial_Peptides.csv",header=None,index_col=None)
b2=data2.values[:,2] 
ACC2 = []
for i in range(len(b2)):
#     print b[i]
    ACC2.append(b2[i])
# name = ",".join(name.split())
c2=data2.values[:,6] 

MCC2 = []
for i in range(len(c2)):
#     print c[i]
    MCC2.append(c2[i])
    
    x = range(len(name))

# plt.figure(figsize=(10,5), dpi=200,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=108)
# ax=plt.subplot(222)

ax=plt.subplot2grid((2,2), (0,0), colspan=1)
# ax=plt.subplot(221)
plt.plot(x, ACC1, marker='o', ms=3,label=u'ACC-FT(80)')
plt.plot(x, MCC1, marker='*', ms=3,label=u'MCC-FT(80)')
plt.xticks(x, name, rotation=90, fontsize="6")
# plt.text(3.8,0.915,'0.912',fontsize='12')
# plt.text(17,0.925,'0.921',fontsize='12')
plt.legend(loc="lower right" )  # 让图例生效

# plt.xlim([-0.03, 46])
plt.ylim([0.4, 0.96])
# plt.xlabel('False Positive Rate')
plt.ylabel('Performance(%)')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-10,0.935,'A',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")


ax=plt.subplot2grid((2,2), (0,1), colspan=1)
plt.plot(x, ACC2, marker='o', ms=3,label=u'ACC-FT(92)')
plt.plot(x, MCC2, marker='*', ms=3,label=u'MCC-FT(92)')
plt.xticks(x, name, rotation=90, fontsize="6")
plt.legend(loc="lower right" )  # 让图例生效

# plt.xlim([-0.03, 46])
plt.ylim([0.4, 0.96])
# plt.xlabel('False Positive Rate')
plt.ylabel('Performance(%)')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-10,0.935,'B',fontsize='xx-large')
# plt.text(3.8,0.832,'0.825',fontsize='12')
# plt.text(17,0.849,'0.842',fontsize='12')
plt.legend(loc="lower right",fontsize="8")

data=pd.read_csv(r"C:\Users\Administrator\Desktop\\Peptides_optim\Anti-angiogenic_Peptides\fastadata\Result_FT80Anti-angiogenic_Peptides.csv",header=None,index_col=None)
# y1 = auc(fpr, tpr)
a=data.values[:,1]
name = []
for i in range(len(a)):
#     print a[i]
    name .append(a[i])
    
b=data.values[:,2] 
ACC1 = []
for i in range(len(b)):
#     print b[i]
    ACC1.append(b[i])
# name = ",".join(name.split())
c=data.values[:,6] 

MCC1 = []
for i in range(len(c)):
#     print c[i]
    MCC1.append(c[i])
# y1 = y.replace(' ', '，')
# print  ACCc
# x = range(len(y1))
data2=pd.read_csv(r"C:\Users\Administrator\Desktop\Peptides_optim\Anti-bacterial_Peptides\fastadata\Result_FT92Anti-bacterial_Peptides.csv",header=None,index_col=None)
b2=data2.values[:,2] 
ACC2 = []
for i in range(len(b2)):
#     print b[i]
    ACC2.append(b2[i])
# name = ",".join(name.split())
c2=data2.values[:,6] 

MCC2 = []
for i in range(len(c2)):
#     print c[i]
    MCC2.append(c2[i])
    
    x = range(len(name))

# plt.figure(figsize=(10,5), dpi=200,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=108)
# ax=plt.subplot(222)

ax=plt.subplot2grid((2,2), (1,0), colspan=1)
# ax=plt.subplot(221)
plt.plot(x, ACC1, marker='o', ms=3,label=u'ACC-FT(80)')
plt.plot(x, MCC1, marker='*', ms=3,label=u'MCC-FT(80)')
plt.xticks(x, name, rotation=90, fontsize="6")
# plt.text(3.8,0.915,'0.912',fontsize='12')
# plt.text(17,0.925,'0.921',fontsize='12')
plt.legend(loc="lower right" )  # 让图例生效

# plt.xlim([-0.03, 46])
plt.ylim([0.4, 0.96])
# plt.xlabel('False Positive Rate')
plt.ylabel('Performance(%)')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-10,0.935,'C',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")


ax=plt.subplot2grid((2,2), (1,1), colspan=1)
plt.plot(x, ACC2, marker='o', ms=3,label=u'ACC-FT(92)')
plt.plot(x, MCC2, marker='*', ms=3,label=u'MCC-FT(92)')
plt.xticks(x, name, rotation=90, fontsize="6")
plt.legend(loc="lower right" )  # 让图例生效

# plt.xlim([-0.03, 46])
plt.ylim([0.4, 0.96])
# plt.xlabel('False Positive Rate')
plt.ylabel('Performance(%)')
# plt.text(0.2,0.6,'ROC curves on CPP924',fontsize='x-large')
# plt.text(-0.13,0.98,'F',fontsize='xx-large')
plt.text(-10,0.935,'D',fontsize='xx-large')
# plt.text(3.8,0.832,'0.825',fontsize='12')
# plt.text(17,0.849,'0.842',fontsize='12')
plt.legend(loc="lower right",fontsize="8")

plt.savefig('C:\Users\Administrator\Desktop\ACC.pdf',bbox_inches='tight')
plt.show()
