# %%
# encoding=utf-8
import matplotlib.pyplot as plt
from pylab import *                                 #支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
myfont = matplotlib.font_manager.FontProperties(size=24) 
plt.figure(figsize=(12,12), dpi=300,facecolor=(1, 1, 1))
# plt.subplot(321)
names = ['FT1','FT5','FT9','FT13','FT17','FT21','FT25','FT29','FT33','FT37','FT41','FT45','FT49','FT53','FT57','FT61','FT65','FT69','FT73','FT77','FT81','FT85','FT89','FT93','FT97'
    ]
x = range(len(names))
y = [0.623,0.808,0.863,0.933,0.928,0.930,0.925,0.925,0.928,0.925,0.928,0.920,0.920,0.928,0.925,0.933,0.928,0.928,0.923,0.925,0.923,0.923,0.925,0.923,0.923
]
y1=[0.245,0.615,0.725,0.865,0.856,0.860,0.850,0.850,0.855,0.850,0.855,0.840,0.840,0.855,0.850,0.865,0.855,0.855,0.845,0.850,0.845,0.845,0.850,0.845,0.845
]
y2=[0.725,0.889,0.932,0.970,0.974,0.976,0.974,0.975,0.974,0.972,0.975,0.974,0.975,0.970,0.974,0.975,0.973,0.974,0.974,0.973,0.973,0.973,0.974,0.975,0.974
]
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
#pl.ylim(-1, 110)  # 限定纵轴的范围
plt.plot(x, y, marker='o', mec='r', mfc='w',label=u'ACC')
plt.plot(x, y1, marker='*', ms=10,label=u'MCC')
plt.plot(x, y2, marker='x', ms=10,label=u'AUC')
plt.legend(loc="lower right" ,prop=myfont)  # 让图例生效
plt.xticks(x, names, rotation=45)
# plt.margins(0)
plt.subplots_adjust(bottom=0.15)
plt.xlabel(u"Feature") #X轴标签
plt.ylabel("percentage") #Y轴标签
plt.title("FT RESULT") #标题
plt.savefig('C:/Users/Administrator/Desktop/AvgSD.pdf',bbox_inches='tight')
