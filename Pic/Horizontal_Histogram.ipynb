# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

plt.figure(figsize=(13,10), dpi=200,facecolor=(1, 1, 1))
plt.subplots_adjust(wspace =0.45, hspace =0.42)#调整子图间距


ax=plt.subplot2grid((3,3), (0,0), colspan=1)

plt.title("Anti-angiogenic Peptides",fontsize="10")#设置剃头了
#数据
name=[ 'ASDC  ','AAC(N=1)  ','OLP(NTCT=5)   ','BIT21 (NTCT =5)','AAC(N=1;NTCT=5)','F26']
colleges=[400,20,100,210,20,26]
b=ax.barh(range(len(name)),colleges,color='#7FFFD4',edgecolor = 'black')
#添加数据标签
for rect in b:
    w=rect.get_width()
    ax.text(w,rect.get_y()+rect.get_height()/2,'%d'%int(w),ha='left',va='center')

#设置Y轴刻度线标签
ax.set_yticks(range(len(name)))
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
# ax.set_yticklabels(name)
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
ax.set_yticklabels(name,fontsize="8")
plt.text(-68.15,5.5,'A',fontsize='xx-large')
plt.xlim([0, 480])
plt.xlabel('Feature Dimension')

ax=plt.subplot2grid((3,3), (0,1), colspan=1)

plt.title("Anti-bacterial Peptides",fontsize="10")#设置剃头了
#数据
name=[ 'ASDC ',' GGAP(G=1) ','AAC(N=1) ','GGAP(G=0)','188D','F61']
colleges=[400,400,20,400,100,61]
b=ax.barh(range(len(name)),colleges,color='#7FFFD4',edgecolor = 'black')
#添加数据标签
for rect in b:
    w=rect.get_width()
    ax.text(w,rect.get_y()+rect.get_height()/2,'%d'%int(w),ha='left',va='center')

#设置Y轴刻度线标签
ax.set_yticks(range(len(name)))
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
# ax.set_yticklabels(name)
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
ax.set_yticklabels(name,fontsize="8")
plt.text(-68.15,5.5,'B',fontsize='xx-large')
plt.xlim([0, 480])
plt.xlabel('Feature Dimension')

ax=plt.subplot2grid((3,3), (0,2), colspan=1)

plt.title("Anti-cancer Peptides",fontsize="10")#设置剃头了
#数据
name=[ 'BIT20(NTCT=2)  ','BIT21(NT=2)  ','BIT20(NT=2)','BIT20(NTCT=3)','BIT20(NT=4)','F45']
colleges=[80,42,40,120,80,45]
b=ax.barh(range(len(name)),colleges,color='#7FFFD4',edgecolor = 'black')
#添加数据标签
for rect in b:
    w=rect.get_width()
    ax.text(w,rect.get_y()+rect.get_height()/2,'%d'%int(w),ha='left',va='center')

#设置Y轴刻度线标签
ax.set_yticks(range(len(name)))
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
# ax.set_yticklabels(name)
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
ax.set_yticklabels(name,fontsize="8")
plt.text(-68.15,5.5,'C',fontsize='xx-large')
plt.xlim([0, 480])
plt.xlabel('Feature Dimension')

ax=plt.subplot2grid((3,3), (1,0), colspan=1)

plt.title("Anti-inflammatory Peptides",fontsize="10")#设置剃头了
#数据
name=[ 'GGAP(G=1)  ','CTD ','AAC(N=1)','188D','GGAP(G=0)','F89']
colleges=[400,63,20,188,400,89]
b=ax.barh(range(len(name)),colleges,color='#7FFFD4',edgecolor = 'black')
#添加数据标签
for rect in b:
    w=rect.get_width()
    ax.text(w,rect.get_y()+rect.get_height()/2,'%d'%int(w),ha='left',va='center')

#设置Y轴刻度线标签
ax.set_yticks(range(len(name)))
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
# ax.set_yticklabels(name)
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
ax.set_yticklabels(name,fontsize="8")
plt.text(-68.15,5.5,'D',fontsize='xx-large')
plt.xlim([0, 480])
plt.xlabel('Feature Dimension')

ax=plt.subplot2grid((3,3), (1,1), colspan=1)

plt.title("Anti-viral Peptides",fontsize="10")#设置剃头了
#数据
name=[ 'GGAP(G=0)  ','ASDC  ','AAC(N=2) ','GGAP(G=2)','GGAP(G=1)','F89']
colleges=[400,400,20,400,400,89]
b=ax.barh(range(len(name)),colleges,color='#7FFFD4',edgecolor = 'black')
#添加数据标签
for rect in b:
    w=rect.get_width()
    ax.text(w,rect.get_y()+rect.get_height()/2,'%d'%int(w),ha='left',va='center')

#设置Y轴刻度线标签
ax.set_yticks(range(len(name)))
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
# ax.set_yticklabels(name)
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
ax.set_yticklabels(name,fontsize="8")
plt.text(-68.15,5.5,'E',fontsize='xx-large')
plt.xlim([0, 480])
plt.xlabel('Feature Dimension')

ax=plt.subplot2grid((3,3), (1,2), colspan=1)

plt.title("Cell-penetrating Peptidess",fontsize="10")#设置剃头了
#数据
name=[ 'AAC(N=1) ','ASDC','188D','GGAP(G=0)','GGAP(G=2)','F96']
colleges=[20,400,188,400,400,96]
b=ax.barh(range(len(name)),colleges,color='#7FFFD4',edgecolor = 'black')
#添加数据标签
for rect in b:
    w=rect.get_width()
    ax.text(w,rect.get_y()+rect.get_height()/2,'%d'%int(w),ha='left',va='center')

#设置Y轴刻度线标签
ax.set_yticks(range(len(name)))
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
# ax.set_yticklabels(name)
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
ax.set_yticklabels(name,fontsize="8")
plt.text(-68.15,5.5,'F',fontsize='xx-large')
plt.xlim([0, 480])
plt.xlabel('Feature Dimension')

ax=plt.subplot2grid((3,3), (2,0), colspan=1)

plt.title("Quorum-Sensing Peptides",fontsize="10")#设置剃头了
#数据
name=[ 'GGAP(G=0)  ','GGAP(G=2)  ','188D ','CTD','AAC(N=1)','F92']
colleges=[400,400,188,63,20,92]
b=ax.barh(range(len(name)),colleges,color='#7FFFD4',edgecolor = 'black')
#添加数据标签
for rect in b:
    w=rect.get_width()
    ax.text(w,rect.get_y()+rect.get_height()/2,'%d'%int(w),ha='left',va='center')

#设置Y轴刻度线标签
ax.set_yticks(range(len(name)))
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
# ax.set_yticklabels(name)
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
ax.set_yticklabels(name,fontsize="8")
plt.text(-68.15,5.5,'G',fontsize='xx-large')
plt.xlim([0, 480])
plt.xlabel('Feature Dimension')

ax=plt.subplot2grid((3,3), (2,1), colspan=1)

plt.title("Surface-Binding Peptides",fontsize="10")#设置剃头了
#数据
name=[ 'AAC(N=1)  ','188D  ','ASDC  ','GGAP(G=3) ','OLP(NT=4)','F8']
colleges=[20,188,400,400,40,8]
b=ax.barh(range(len(name)),colleges,color='#7FFFD4',edgecolor = 'black')
#添加数据标签
for rect in b:
    w=rect.get_width()
    ax.text(w,rect.get_y()+rect.get_height()/2,'%d'%int(w),ha='left',va='center')

#设置Y轴刻度线标签
ax.set_yticks(range(len(name)))
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
# ax.set_yticklabels(name)
#font=FontProperties(fname=r'/Library/Fonts/Songti.ttc')
ax.set_yticklabels(name,fontsize="8")
plt.text(-68.15,5.5,'H',fontsize='xx-large')
plt.xlim([0, 480])
plt.xlabel('Feature Dimension')



plt.savefig('C:\Users\Administrator\Desktop\Fea_Dimension.pdf',bbox_inches='tight')
# plt.show()
