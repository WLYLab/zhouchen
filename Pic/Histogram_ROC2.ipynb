# %%
#!/usr/bin/env python
# encoding:utf-8
# print(__doc__)



import numpy as np
import pandas as pd
from scipy import interp
import matplotlib.pyplot as plt
import pylab

import matplotlib
from itertools import cycle
from sklearn import svm
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(12,8), dpi=300,facecolor=(1, 1, 1))
# plt.subplots()
# plt.tight_layout(h_pad=1.08)
plt.subplot(224)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\csv\400D45.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',color='#008B45',linewidth=0.5,label=r'ASDC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\bit20ntct1.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-',color = '#EEC900',linewidth=0.5,label=r'BIT20(k=1)(AUC=%.2f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\scpse44.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'y-',color = '#36648B',linewidth=0.5,label=r"SC-PseAAC(AUC=%.2f)"%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\pcpse43.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EE8262',linewidth=0.5,label=r'PC-PseAAC'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\GAP38.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',color = '#8B6914',linewidth=0.5,label=r'GGAP(g=7)(AUC=%.2f)'%roc_auc)
# plt.plot(fpr, tpr,'y-',color = '#36648B',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\OVntct30.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#71C671',linewidth=0.5,label=r'OLP(k=10)(AUC=%.2f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\FT19.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B7355',linewidth=0.5,label=r'FT19(AUC=%.2f)'%roc_auc)


plt.xlim([-0.03, 1])
plt.ylim([0, 1.03])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.text(0.4,0.6,'Independent test',fontsize='x-large')
# plt.text(0.4,0.53,'evaluated by NB',fontsize='x-large')
plt.text(-0.16,0.98,'D',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")

plt.subplot(223)


y1 = [0.908,0.89,0.926,0.817]#独立测试集
y2 = [0.71,0.74,0.68,0.447]
y3 = [0.902,0.874,0.929,0.743]
y4 = [0.903,0.879,0.926,0.421]
y5 = [0.859,0.846,0.872,0.627]
y6 = [0.833,0.784,0.883,0.775]
y7 = [0.921,0.924,0.918,0.842]


ind = np.arange(4)+2               # the x locations for the groups
width = 0.125
plt.bar(ind,y1,width,color = '#008B45',label = 'ASDC ',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'BIT20(k=1)',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = "SC-PseAAC",edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'SC-PseAAC',edgecolor = 'black')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'GGAP(g=7) ',edgecolor = 'black')
plt.bar(ind+5*width,y6,width,color = '#71C671',label = 'OLP(k=10)',edgecolor = 'black')
plt.bar(ind+6*width,y7,width,color = '#8B7355',label = 'FT19',edgecolor = 'black')
plt.xticks(np.arange(4)+0.5 + 15*width, ('ACC','SE','SP','MCC'))
plt.text(1.15,0.99,'C',fontsize='xx-large')
plt.legend(loc="upper right",fontsize="6.5")

# plt.title('Independent test')
# Independent Test
plt.ylim(0.4, 1.03)

plt.subplot(222)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\csv\400D45.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color='#008B45',linewidth=0.5,label=r'ASDC(AUC=%.2f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\OVntct21.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EEC900',linewidth=0.5,label=r'OLP(k=1(AUC=%.2f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\GAP35.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#36648B',linewidth=0.5,label=r"GGAP(g=4)(AUC=%.2f)"%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\bit20ntct1.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:,0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#EE8262',linewidth=0.5,label=r'BIT20 (k=1)(AUC=%.2f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\CTD41.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B6914',linewidth=0.5,label=r'CTD(AUC=%.2f)'%roc_auc)
# plt.plot(fpr, tpr,'y--',color = '#36648B',label=r"Hajisharifi's_method(AUC=%.2f)"%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\GAP32.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#71C671',linewidth=0.5,label=r'GGAP(g=1)(AUC=%.2f)'%roc_auc)
data=pd.read_csv(r"C:\Users\Administrator\Desktop\CPP\csv\FT6.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,1], data.values[:, 0])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'-',color = '#8B7355',linewidth=0.5,label=r'FT6(AUC=%.2f)'%roc_auc)

plt.xlim([-0.03, 1])
plt.ylim([0, 1.03])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.text(0.4,0.6,'Ten-fold cross validation',fontsize='x-large')
# plt.text(0.4,0.53,'evaluated by RF',fontsize='x-large')
plt.text(-0.16,0.98,'B',fontsize='xx-large')
plt.legend(loc="lower right",fontsize="8")
plt.subplot(221)

# params={
# # # #     'axes.labelsize': '35',
# # # #     'xtick.labelsize':'27',
# # # #     'ytick.labelsize':'27',
# # # #     'lines.linewidth':2 ,
#      'legend.fontsize': '5.5',
 
# }
# pylab.rcParams.update(params)


y1 = [0.908,0.89,0.926,0.817]#独立测试集
y2 = [0.723,0.753,0.693,0.447]
y3 = [0.871,0.885,0.857,0.743]
y4 = [0.71,0.74,0.68,0.421]
y5 = [0.813,0.781,0.844,0.627]
y6 = [0.887,0.9,0.874,0.775]
y7 = [0.91,0.92,0.905,0.825]






ind = np.arange(4)+2                # the x locations for the groups
width = 0.125
plt.bar(ind,y1,width,color = '#008B45',label = 'ASDC ',edgecolor = 'black')  
plt.bar(ind+width,y2,width,color = '#EEC900',label = 'OLP(k=1)',edgecolor = 'black') # ind+width adjusts the left start location of the bar.
plt.bar(ind+2*width,y3,width,color = '#36648B',label = "GGAP(g=4)",edgecolor = 'black')
plt.bar(ind+3*width,y4,width,color = '#EE8262',label = 'BIT20 (k=1)',edgecolor = 'black')
plt.bar(ind+4*width,y5,width,color = '#8B6914',label = 'CTD ',edgecolor = 'black')
plt.bar(ind+5*width,y6,width,color = '#71C671',label = 'GGAP(g=1)',edgecolor = 'black')
plt.bar(ind+6*width,y7,width,color = '#8B7355',label = 'FT6',edgecolor = 'black')
plt.xticks(np.arange(4)+0.5 + 15*width, ('ACC','SE','SP','MCC'))

plt.legend(loc="upper right",fontsize="6.5")
# plt.title('Ten-fold cross validation')
plt.text(1.15,0.99,'A',fontsize='xx-large')
# Independent Test
plt.ylim(0.4, 1.03)
plt.savefig('C:\Users\Administrator\Desktop\ROC_1.pdf',bbox_inches='tight')
# plt.show()
